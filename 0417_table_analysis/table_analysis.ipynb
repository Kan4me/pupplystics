# %% [markdown]
# # Analysis
#
# Creating relations between all columns with the effect measuments one to undestand their pattern and interference

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("table.txt", dtype='unicode')
df = df.drop(['line'], axis=1)
df.iloc[:5]
# Out:
#   test_id test_cas organism_lifestage species_number organism_age_mean  \
# 0      13    50293                 NR           5022                NR
# 1      13    50293                 NR           5022                NR
# 2      13    50293                 NR           5022                NR
# 3      13    50293                 NR           5022                NR
# 4      13    50293                 NR           5022                NR
#
#   organism_gender study_duration_mean exposure_duration_mean test_type  \
# 0              NR                   8                      8        NC
# 1              NR                   8                      8        NC
# 2              NR                   8                      8        NC
# 3              NR                   8                      8        NC
# 4              NR                   8                      8        NC
#
#   num_doses_mean  ... cas_number    chem_name formulation chemical_name  \
# 0              1  ...      67641  2-Propanone          NR   2-Propanone
# 1              1  ...      67641  2-Propanone          NR   2-Propanone
# 2              1  ...      67641  2-Propanone          NR   2-Propanone
# 3              1  ...      67641  2-Propanone          NR   2-Propanone
# 4              1  ...      67641  2-Propanone          NR   2-Propanone
#
#         common_name   kingdom        class    tax_order          family  \
# 0  Indian Earthworm  Animalia  Oligochaeta  Haplotaxida  Megascolecidae
# 1  Indian Earthworm  Animalia  Oligochaeta  Haplotaxida  Megascolecidae
# 2  Indian Earthworm  Animalia  Oligochaeta  Haplotaxida  Megascolecidae
# 3  Indian Earthworm  Animalia  Oligochaeta  Haplotaxida  Megascolecidae
# 4  Indian Earthworm  Animalia  Oligochaeta  Haplotaxida  Megascolecidae
#
#     species
# 0  posthuma
# 1  posthuma
# 2  posthuma
# 3  posthuma
# 4  posthuma
#
# [5 rows x 35 columns]

# %%
df.drop(df.loc[df['effect']!='MOR'].index, inplace=True)
df.iloc[:5]
# Out:
#      test_id  test_cas organism_lifestage species_number organism_age_mean  \
# 32     48691  10108642                 MA           5022                NR
# 33     48691  10108642                 MA           5022                NR
# 34     48691  10108642                 MA           5022                NR
# 35     48691  10108642                 MA           5022                NR
# 1206      50  32774166                 AD          28839                NR
#
#      organism_gender study_duration_mean exposure_duration_mean test_type  \
# 32                NR                  75                     NR        NC
# 33                NR                  75                     NR        NC
# 34                NR                  75                     NR        NC
# 35                NR                  75                     NR        NC
# 1206          Female                 135                    135        NC
#
#      num_doses_mean  ... cas_number    chem_name formulation chemical_name  \
# 32                4  ...    7732185        Water          NR         Water
# 33                4  ...    7732185        Water          NR         Water
# 34                4  ...    7732185        Water          NR         Water
# 35                4  ...    7732185        Water          NR         Water
# 1206              3  ...      67641  2-Propanone          NR   2-Propanone
#
#            common_name   kingdom        class    tax_order          family  \
# 32    Indian Earthworm  Animalia  Oligochaeta  Haplotaxida  Megascolecidae
# 33    Indian Earthworm  Animalia  Oligochaeta  Haplotaxida  Megascolecidae
# 34    Indian Earthworm  Animalia  Oligochaeta  Haplotaxida  Megascolecidae
# 35    Indian Earthworm  Animalia  Oligochaeta  Haplotaxida  Megascolecidae
# 1206     American Mink  Animalia     Mammalia    Carnivora      Mustelidae
#
#        species
# 32    posthuma
# 33    posthuma
# 34    posthuma
# 35    posthuma
# 1206     vison
#
# [5 rows x 35 columns]

# %% [markdown]
# Here we will try to get the relation of a specific value in the Species column with the effect Measument column

# %% [markdown]
# # Trying to create a filter
#
# The ideia is to understand how to create analysis betweet species and mortality

# %%
cols       = df.columns

table_cols = []
for c in cols.values:
    if c   != 'measurement':
        table_cols.append(c)

# %%
for c in table_cols:
    df.loc[df[c].isnull(),c] = 0
    
df.describe()
# Out:
#        test_id test_cas organism_lifestage species_number organism_age_mean  \
# count   134451   134451             134451         134451            134451
# unique    1542      347                 27            143                40
# top      53272    60571                 JV           4510                NR
# freq     16170    32210              74857          78737            101211
#
#        organism_gender study_duration_mean exposure_duration_mean test_type  \
# count           134451              134451                 134451    134451
# unique               4                  77                     77         2
# top               Both                  37                     36        NC
# freq            108613               52658                  51938    134428
#
#        num_doses_mean  ... cas_number chem_name formulation chemical_name  \
# count          134451  ...     134451    134451      134451        134451
# unique             13  ...         59        59           7            59
# top                 6  ...      64175   Ethanol          NR       Ethanol
# freq            64808  ...      59849     59849      133242         59849
#
#        common_name   kingdom     class  tax_order   family     species
# count       134451    134451    134451     134451   134451      134451
# unique         125         2        15         46       82         122
# top     Norway Rat  Animalia  Mammalia   Rodentia  Muridae  norvegicus
# freq         78737    132468     99057      96081    95948       78737
#
# [4 rows x 35 columns]

# %%
measurement_dict = df['measurement'].value_counts().to_dict()
measurement_dict
# Out:
# {'GMOR/': 93791,
#  'MORT': 29550,
#  'SURV': 9187,
#  'TDTH': 981,
#  'HTCH': 745,
#  'GMOR': 145,
#  'TKNO': 27,
#  'MDTH': 13,
#  'TLET': 6,
#  'SVVS': 5,
#  'LFSP': 1}

# %% [markdown]
# Recorrence number for all values in each column

# %%
value_counts_dict = {c: dict(df[c].value_counts()) for c in table_cols}
value_counts_dict

# %%
df_clone = df # Just a df restart for test

# %% [markdown]
# The relation table will have the value for each species in effect Measument  values

# %%
df_columns  = list(measurement_dict.keys())
df_columns  = ["Species"] + df_columns

df_new      = pd.DataFrame(columns = df_columns)

df_new

# %% [markdown]
# All the values for this tets table

# %%
df_trash  = df[df.species == 'norvegicus']

new_list  = []
for m in measurement_dict.keys():
    df_t  = df_trash[df_trash.measurement == m]
    new_list.append(str(df_t.shape[0]))

new_list.insert(0,'norvegicus')

new_list
a         = np.array(new_list)
new_list  = a.transpose().tolist()

print(new_list)
print(df_columns)

# %% [markdown]
# Creating the final test table

# %%
current_row = pd.DataFrame([new_list], columns=df_columns)

current_row

# %% [markdown]
# Creating dict to get each value as unique id

# %%
species_dict = df['species'].value_counts().to_dict()
species_dict

# %% [markdown]
# Since the example worked, now we'll create an automatizated solution for all values in all columns

# %%
# for m in measurement_dict.keys():
#     new_df  = df.columns=[m]
    
# for s in species_dict.keys():
#     new_df  = df(rows=[s])
    
# for m in measurement_dict.keys():
#     new_df    = df[ df.measurement == m ]
#     for s in species_dict.keys():
        
#         new_df = df[df.species == s]
        
#         new_df[m][a] = df['measurement'].value_counts().to_dict().shape[0]

# %%
for m in measurement_dict.keys():
    new_df  = df.columns=[m]
print(new_df)
    
for s in species_dict.keys():
    new_df  = df(rows=[s])
print(new_df)

new_list  = []
for m in measurement_dict.keys():
    new_df    = df[ df.measurement == m ]
    for s in species_dict.keys():
        new_list.insert(0,s)
        new_df = df[df.species == s]
        new_df[m][a] = df['measurement'].value_counts().to_dict().shape[0]
        
a         = np.array(new_list)
new_list  = a.transpose().tolist()
current_row = pd.DataFrame([new_list], columns=df_columns)

# %% [markdown]
# # Using query
#
# Creating a filter proved to be a hard way to to something that there's already concepts in python that will help out

# %% [markdown]
# This function will show how many times a specific type of mortality effect occur for each species. As for example:
#
# andrei
# GMOR/           814
#
# MORT            138
#
# Andrei is a worm and it lives in compost or leaf litter. Also, in experimenting with this species, there was 814 cases of GMOR (this reference can be seen in past analysis) and 138 MORT, or 14% of Andrei had MORT effect with MORT measurement.

# %%
n = df.query('effect == "MOR"')
speciesMeasurement = n.groupby(['species', 'measurement']).size()
speciesMeasurement
# Out:
# species       measurement
# aegypti       MORT             31
# alba          GMOR/          1260
# americana     MORT             15
# andrei        GMOR/           814
#               MORT            138
# aries         MORT            701
# armata        MORT              2
#               SURV              6
# armigera      MORT              8
# arvensis      MORT              1
# aspersa       MORT              4
# ater          MORT            104
# auratus       MORT             10
#               SURV            135
# auritus       SURV            215
# blomhoffii    MORT              2
# brassicae     SURV              1
# brunneus      MORT              1
# caliginosa    MORT             79
#               SURV              5
# candida       MORT           1174
#               SURV            224
# castaneum     MORT              3
#               TLET              2
# catesbeiana   MORT              5
# chlorotica    SURV              5
# cincta        GMOR              1
# coffeella     MORT             39
# colchicus     GMOR/          5192
#               MORT            168
#                              ...
# saucia        MORT             12
# scaber        MORT            106
# scandens      MORT              3
# scripta       MORT              3
# scrofa        MORT            882
# sp.           GMOR/          1052
#               MORT            186
#               SURV              1
# sparverius    GMOR/           630
#               MORT            219
# sponsa        SURV              1
# stephensi     GMOR              4
#               MORT             59
# terrestris    MORT           3808
# trivittatus   MORT              4
# unguiculatus  GMOR/             6
#               MORT              5
# unicolor      GMOR             49
#               TKNO             10
# urticae       MORT              9
# v-nigrum      MORT             11
# veneta        MORT             18
# virescens     MORT             56
# virginianus   MORT            689
# vison         MORT            348
# vulgare       MORT              1
# vulgaris      MORT             46
#               SURV              2
# woodi         MORT              4
# zea           MORT             11
# Length: 166, dtype: int64

# %%
n['species']
# Out:
# 32         posthuma
# 33         posthuma
# 34         posthuma
# 35         posthuma
# 1206          vison
# 1207          vison
# 1208          vison
# 1209          vison
# 1210          vison
# 1211          vison
# 1212          vison
# 1213          vison
# 1214          vison
# 1215          vison
# 1216          vison
# 1217          vison
# 1218          vison
# 1219          vison
# 1220          vison
# 1221          vison
# 1222          vison
# 1223          vison
# 1224          vison
# 1225          vison
# 1226          vison
# 1227          vison
# 1228          vison
# 1229          vison
# 1230          vison
# 1231          vison
#              ...
# 1630068     glabrum
# 1630069     glabrum
# 1630070     glabrum
# 1630071     glabrum
# 1630072     glabrum
# 1630073     glabrum
# 1630074     glabrum
# 1630075     glabrum
# 1630076     glabrum
# 1630077     glabrum
# 1630078     glabrum
# 1630079     glabrum
# 1630080     glabrum
# 1630081     glabrum
# 1630082     glabrum
# 1630083     glabrum
# 1630084     glabrum
# 1630085     glabrum
# 1630086     glabrum
# 1630087     glabrum
# 1630088     glabrum
# 1630089     glabrum
# 1630090     glabrum
# 1630091     glabrum
# 1630092     glabrum
# 1630093     glabrum
# 1630094     glabrum
# 1630095     glabrum
# 1630096     glabrum
# 1630097     glabrum
# Name: species, Length: 134451, dtype: object

# %%
set(df['measurement'])
# Out:
# {'GMOR',
#  'GMOR/',
#  'HTCH',
#  'LFSP',
#  'MDTH',
#  'MORT',
#  'SURV',
#  'SVVS',
#  'TDTH',
#  'TKNO',
#  'TLET'}

# %%
n.groupby(['species', 'measurement']).describe()
# Out:
#                          test_id                      test_cas         \
#                            count unique     top  freq    count unique
# species      measurement
# aegypti      MORT             31     31  520108     1       31      7
# alba         GMOR/          1260      2   51883   672     1260      2
# americana    MORT             15      2    2867    12       15      2
# andrei       GMOR/           814      4   46559   350      814      3
#              MORT            138      9   46244    56      138      4
# aries        MORT            701      6   51748   627      701      6
# armata       MORT              2      2   57535     1        2      1
#              SURV              6      6  423499     1        6      1
# armigera     MORT              8      8  554859     1        8      5
# arvensis     MORT              1      1   53989     1        1      1
# aspersa      MORT              4      4   49828     1        4      4
# ater         MORT            104      6   54775    85      104      3
# auratus      MORT             10     10  561684     1       10      2
#              SURV            135      2   53649   106      135      2
# auritus      SURV            215      8   54933   208      215      2
# blomhoffii   MORT              2      2  556170     1        2      2
# brassicae    SURV              1      1  423614     1        1      1
# brunneus     MORT              1      1  521481     1        1      1
# caliginosa   MORT             79      4   46857    20       79      2
#              SURV              5      5   54282     1        5      5
# candida      MORT           1174    119    5289    10     1174     32
#              SURV            224     23    5021    16      224      8
# castaneum    MORT              3      3  537000     1        3      2
#              TLET              2      2   49804     1        2      1
# catesbeiana  MORT              5      1   48021     5        5      1
# chlorotica   SURV              5      5   53790     1        5      5
# cincta       GMOR              1      1  586971     1        1      1
# coffeella    MORT             39     39  535016     1       39      4
# colchicus    GMOR/          5192      8   53292  1872     5192      3
#              MORT            168      3    2023    96      168      2
# ...                          ...    ...     ...   ...      ...    ...
# saucia       MORT             12      3   48761     4       12      1
# scaber       MORT            106      1   52348   106      106      1
# scandens     MORT              3      3  522981     1        3      3
# scripta      MORT              3      3  474268     1        3      3
# scrofa       MORT            882      2   52374   592      882      1
# sp.          GMOR/          1052     25   51382    44     1052     25
#              MORT            186     14   51793    80      186     13
#              SURV              1      1  591219     1        1      1
# sparverius   GMOR/           630      2   53903   480      630      2
#              MORT            219      4   53020   191      219      3
# sponsa       SURV              1      1  562660     1        1      1
# stephensi    GMOR              4      4  579194     1        4      1
#              MORT             59     59  579061     1       59      3
# terrestris   MORT           3808     25   47413   756     3808     22
# trivittatus  MORT              4      2   51560     2        4      2
# unguiculatus GMOR/             6      1    2672     6        6      1
#              MORT              5      1   54151     5        5      1
# unicolor     GMOR             49     49  550787     1       49     21
#              TKNO             10     10  551024     1       10      7
# urticae      MORT              9      9  428586     1        9      1
# v-nigrum     MORT             11     11  572095     1       11     11
# veneta       MORT             18      1   49766    18       18      1
# virescens    MORT             56     56  556672     1       56     12
# virginianus  MORT            689     12     458   492      689      4
# vison        MORT            348      1      50   348      348      1
# vulgare      MORT              1      1   52394     1        1      1
# vulgaris     MORT             46      1   53584    46       46      1
#              SURV              2      2  432315     1        2      2
# woodi        MORT              4      4  450382     1        4      1
# zea          MORT             11     11  512697     1       11      6
#
#                                           organism_lifestage         ...  \
#                                 top  freq              count unique  ...
# species      measurement                                             ...
# aegypti      MORT          52645531     7                 31      1  ...
# alba         GMOR/            72559   672               1260      1  ...
# americana    MORT             60571    12                 15      1  ...
# andrei       GMOR/           118967   362                814      1  ...
#              MORT            118967   108                138      1  ...
# aries        MORT           7646799   627                701      3  ...
# armata       MORT            129000     2                  2      1  ...
#              SURV            129000     6                  6      1  ...
# armigera     MORT          71751412     3                  8      1  ...
# arvensis     MORT           1773371     1                  1      1  ...
# aspersa      MORT            122145     1                  4      1  ...
# ater         MORT             50293    90                104      1  ...
# auratus      MORT           3813147     7                 10      1  ...
#              SURV             72559   106                135      1  ...
# auritus      SURV             50293   208                215      2  ...
# blomhoffii   MORT            127902     1                  2      1  ...
# brassicae    SURV         161050584     1                  1      1  ...
# brunneus     MORT          12789036     1                  1      1  ...
# caliginosa   MORT           7758987    40                 79      1  ...
#              SURV             63252     1                  5      1  ...
# candida      MORT             60571    70               1174      2  ...
#              SURV          10108642    60                224      3  ...
# castaneum    MORT          52645531     2                  3      2  ...
#              TLET          52645531     2                  2      1  ...
# catesbeiana  MORT           1746016     5                  5      1  ...
# chlorotica   SURV             63252     1                  5      1  ...
# cincta       GMOR           1912249     1                  1      1  ...
# coffeella    MORT            298044    11                 39      1  ...
# colchicus    GMOR/            60571  3978               5192      2  ...
#              MORT           1746016   144                168      2  ...
# ...                             ...   ...                ...    ...  ...
# saucia       MORT          16752775    12                 12      1  ...
# scaber       MORT             50328   106                106      1  ...
# scandens     MORT          52315078     1                  3      1  ...
# scripta      MORT             72559     1                  3      1  ...
# scrofa       MORT            301042   882                882      1  ...
# sp.          GMOR/           129793    44               1052      1  ...
#              MORT           6080564    80                186      5  ...
#              SURV           1912249     1                  1      1  ...
# sparverius   GMOR/           115322   480                630      2  ...
#              MORT           7439921   191                219      2  ...
# sponsa       SURV            298000     1                  1      1  ...
# stephensi    GMOR          52645531     4                  4      1  ...
#              MORT          29232937    44                 59      1  ...
# terrestris   MORT             63252   758               3808      2  ...
# trivittatus  MORT          52645531     2                  4      1  ...
# unguiculatus GMOR/          7786347     6                  6      1  ...
#              MORT           7786347     5                  5      1  ...
# unicolor     GMOR          26002802    14                 49      1  ...
#              TKNO          23031369     3                 10      1  ...
# urticae      MORT          15708415     9                  9      1  ...
# v-nigrum     MORT            115297     1                 11      1  ...
# veneta       MORT           7718549    18                 18      1  ...
# virescens    MORT          52645531    16                 56      2  ...
# virginianus  MORT             60571   664                689      5  ...
# vison        MORT          32774166   348                348      1  ...
# vulgare      MORT            309002     1                  1      1  ...
# vulgaris     MORT             50293    46                 46      1  ...
#              SURV             60515     1                  2      1  ...
# woodi        MORT          33089611     4                  4      2  ...
# zea          MORT          52315078     6                 11      2  ...
#
#                                   class       tax_order         \
#                                     top  freq     count unique
# species      measurement
# aegypti      MORT               Insecta    31        31      1
# alba         GMOR/                 Aves  1260      1260      1
# americana    MORT               Insecta    15        15      1
# andrei       GMOR/           Clitellata   814       814      1
#              MORT            Clitellata   138       138      1
# aries        MORT              Mammalia   701       701      1
# armata       MORT            Entognatha     2         2      1
#              SURV            Entognatha     6         6      1
# armigera     MORT               Insecta     8         8      1
# arvensis     MORT         Magnoliopsida     1         1      1
# aspersa      MORT            Gastropoda     4         4      1
# ater         MORT                  Aves   104       104      1
# auratus      MORT              Mammalia    10        10      1
#              SURV              Mammalia   135       135      1
# auritus      SURV                  Aves   215       215      1
# blomhoffii   MORT              Reptilia     2         2      1
# brassicae    SURV               Insecta     1         1      1
# brunneus     MORT               Insecta     1         1      1
# caliginosa   MORT            Clitellata    79        79      1
#              SURV            Clitellata     5         5      1
# candida      MORT            Entognatha  1174      1174      1
#              SURV            Entognatha   224       224      1
# castaneum    MORT               Insecta     3         3      1
#              TLET               Insecta     2         2      1
# catesbeiana  MORT              Amphibia     5         5      1
# chlorotica   SURV            Clitellata     5         5      1
# cincta       GMOR            Entognatha     1         1      1
# coffeella    MORT               Insecta    39        39      1
# colchicus    GMOR/                 Aves  5192      5192      1
#              MORT                  Aves   168       168      1
# ...                                 ...   ...       ...    ...
# saucia       MORT               Insecta    12        12      1
# scaber       MORT          Malacostraca   106       106      1
# scandens     MORT               Insecta     3         3      1
# scripta      MORT              Reptilia     3         3      1
# scrofa       MORT              Mammalia   882       882      1
# sp.          GMOR/             Mammalia  1052      1052      1
#              MORT              Mammalia    92       186      5
#              SURV              Reptilia     1         1      1
# sparverius   GMOR/                 Aves   630       630      1
#              MORT                  Aves   219       219      1
# sponsa       SURV                  Aves     1         1      1
# stephensi    GMOR               Insecta     4         4      1
#              MORT               Insecta    59        59      1
# terrestris   MORT            Clitellata  3808      3808      1
# trivittatus  MORT               Insecta     4         4      1
# unguiculatus GMOR/             Mammalia     6         6      1
#              MORT              Mammalia     5         5      1
# unicolor     GMOR               Insecta    49        49      1
#              TKNO               Insecta    10        10      1
# urticae      MORT             Arachnida     9         9      1
# v-nigrum     MORT               Insecta    11        11      1
# veneta       MORT            Clitellata    18        18      1
# virescens    MORT               Insecta    56        56      1
# virginianus  MORT                  Aves   673       689      2
# vison        MORT              Mammalia   348       348      1
# vulgare      MORT          Malacostraca     1         1      1
# vulgaris     MORT                  Aves    46        46      1
#              SURV                  Aves     2         2      1
# woodi        MORT             Arachnida     4         4      1
# zea          MORT               Insecta    11        11      1
#
#                                                 family         \
#                                       top  freq  count unique
# species      measurement
# aegypti      MORT                 Diptera    31     31      1
# alba         GMOR/           Strigiformes  1260   1260      1
# americana    MORT             Dictyoptera    15     15      1
# andrei       GMOR/           Lumbriculida   814    814      1
#              MORT            Lumbriculida   138    138      1
# aries        MORT            Artiodactyla   701    701      1
# armata       MORT              Collembola     2      2      1
#              SURV              Collembola     6      6      1
# armigera     MORT             Lepidoptera     8      8      1
# arvensis     MORT             Brassicales     1      1      1
# aspersa      MORT         Stylommatophora     4      4      1
# ater         MORT           Passeriformes   104    104      1
# auratus      MORT                Rodentia    10     10      1
#              SURV                Rodentia   135    135      1
# auritus      SURV              Suliformes   215    215      1
# blomhoffii   MORT                Squamata     2      2      1
# brassicae    SURV             Hymenoptera     1      1      1
# brunneus     MORT              Coleoptera     1      1      1
# caliginosa   MORT            Lumbriculida    79     79      1
#              SURV            Lumbriculida     5      5      1
# candida      MORT              Collembola  1174   1174      1
#              SURV              Collembola   224    224      1
# castaneum    MORT              Coleoptera     3      3      1
#              TLET              Coleoptera     2      2      1
# catesbeiana  MORT                   Anura     5      5      1
# chlorotica   SURV            Lumbriculida     5      5      1
# cincta       GMOR              Collembola     1      1      1
# coffeella    MORT             Lepidoptera    39     39      1
# colchicus    GMOR/            Galliformes  5192   5192      1
#              MORT             Galliformes   168    168      1
# ...                                   ...   ...    ...    ...
# saucia       MORT             Lepidoptera    12     12      1
# scaber       MORT                 Isopoda   106    106      1
# scandens     MORT             Lepidoptera     3      3      1
# scripta      MORT              Testudines     3      3      1
# scrofa       MORT            Artiodactyla   882    882      1
# sp.          GMOR/               Rodentia  1052   1052      1
#              MORT                Rodentia    91    186      7
#              SURV              Testudines     1      1      1
# sparverius   GMOR/          Falconiformes   630    630      1
#              MORT           Falconiformes   219    219      1
# sponsa       SURV            Anseriformes     1      1      1
# stephensi    GMOR                 Diptera     4      4      1
#              MORT                 Diptera    59     59      1
# terrestris   MORT            Lumbriculida  3808   3808      1
# trivittatus  MORT                 Diptera     4      4      1
# unguiculatus GMOR/               Rodentia     6      6      1
#              MORT                Rodentia     5      5      1
# unicolor     GMOR              Coleoptera    49     49      1
#              TKNO              Coleoptera    10     10      1
# urticae      MORT          Trombidiformes     9      9      1
# v-nigrum     MORT              Coleoptera    11     11      1
# veneta       MORT            Lumbriculida    18     18      1
# virescens    MORT             Lepidoptera    56     56      1
# virginianus  MORT             Galliformes   673    689      2
# vison        MORT               Carnivora   348    348      1
# vulgare      MORT                 Isopoda     1      1      1
# vulgaris     MORT           Passeriformes    46     46      1
#              SURV           Passeriformes     2      2      1
# woodi        MORT          Trombidiformes     4      4      1
# zea          MORT             Lepidoptera    11     11      1
#
#
#                                         top  freq
# species      measurement
# aegypti      MORT                 Culicidae    31
# alba         GMOR/                Tytonidae  1260
# americana    MORT                 Blattidae    15
# andrei       GMOR/              Lumbricidae   814
#              MORT               Lumbricidae   138
# aries        MORT                   Bovidae   701
# armata       MORT              Onychiuridae     2
#              SURV              Onychiuridae     6
# armigera     MORT                 Noctuidae     8
# arvensis     MORT              Brassicaceae     1
# aspersa      MORT                 Helicidae     4
# ater         MORT              Fringillidae   104
# auratus      MORT                   Muridae    10
#              SURV                   Muridae   135
# auritus      SURV         Phalacrocoracidae   215
# blomhoffii   MORT                 Viperidae     2
# brassicae    SURV         Trichogrammatidae     1
# brunneus     MORT              Bostrichidae     1
# caliginosa   MORT               Lumbricidae    79
#              SURV               Lumbricidae     5
# candida      MORT                Isotomidae  1174
#              SURV                Isotomidae   224
# castaneum    MORT             Tenebrionidae     3
#              TLET             Tenebrionidae     2
# catesbeiana  MORT                   Ranidae     5
# chlorotica   SURV               Lumbricidae     5
# cincta       GMOR             Entomobryidae     1
# coffeella    MORT               Lyonetiidae    39
# colchicus    GMOR/              Phasianidae  5192
#              MORT               Phasianidae   168
# ...                                     ...   ...
# saucia       MORT                 Noctuidae    12
# scaber       MORT            Porcellionidae   106
# scandens     MORT                 Noctuidae     3
# scripta      MORT                  Emydidae     3
# scrofa       MORT                    Suidae   882
# sp.          GMOR/                  Muridae  1052
#              MORT                   Muridae    88
#              SURV                  Emydidae     1
# sparverius   GMOR/               Falconidae   630
#              MORT                Falconidae   219
# sponsa       SURV                  Anatidae     1
# stephensi    GMOR                 Culicidae     4
#              MORT                 Culicidae    59
# terrestris   MORT               Lumbricidae  3808
# trivittatus  MORT                 Culicidae     4
# unguiculatus GMOR/                  Muridae     6
#              MORT                   Muridae     5
# unicolor     GMOR                 Anobiidae    49
#              TKNO                 Anobiidae    10
# urticae      MORT             Tetranychidae     9
# v-nigrum     MORT             Coccinellidae    11
# veneta       MORT               Lumbricidae    18
# virescens    MORT                 Noctuidae    56
# virginianus  MORT            Odontophoridae   673
# vison        MORT                Mustelidae   348
# vulgare      MORT           Armadillidiidae     1
# vulgaris     MORT                 Sturnidae    46
#              SURV                 Sturnidae     2
# woodi        MORT              Tarsonemidae     4
# zea          MORT                 Noctuidae    11
#
# [166 rows x 132 columns]

# %%
groups = speciesMeasurement
groups.plot.bar()

# %%
fig, ax = plt.subplots(figsize=(15,7))
speciesMeasurement.unstack().plot(ax=ax)

#data.groupby(['date','type']).count()['amount'].unstack().plot(ax=ax)

# %% [markdown]
# Cant use ```.mean()``` directly in ```n.groupby(['species', 'measurement'])``` because the value is cathegorical.

# %%
n.groupby(['species', 'measurement']).mean()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-17-056eb6fa541b> in <module>
# ----> 1 n.groupby(['species', 'measurement']).mean()
#
# /usr/local/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in mean(self, *args, **kwargs)
#    1130         nv.validate_groupby_func('mean', args, kwargs, ['numeric_only'])
#    1131         try:
# -> 1132             return self._cython_agg_general('mean', **kwargs)
#    1133         except GroupByError:
#    1134             raise
#
# /usr/local/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#      68                             min_count=-1):
#      69         new_items, new_blocks = self._cython_agg_blocks(
# ---> 70             how, alt=alt, numeric_only=numeric_only, min_count=min_count)
#      71         return self._wrap_agged_blocks(new_items, new_blocks)
#      72
#
# /usr/local/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#     141
#     142         if len(new_blocks) == 0:
# --> 143             raise DataError('No numeric types to aggregate')
#     144
#     145         # reset the locs in the blocks to correspond to our
#
# DataError: No numeric types to aggregate
