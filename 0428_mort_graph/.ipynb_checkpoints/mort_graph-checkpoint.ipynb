# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("table.txt", dtype='unicode')
df = df.drop(['line'], axis=1)
df.iloc[:5]
# Out:
#   test_id test_cas organism_lifestage species_number organism_age_mean  \
# 0      13    50293                 NR           5022                NR
# 1      13    50293                 NR           5022                NR
# 2      13    50293                 NR           5022                NR
# 3      13    50293                 NR           5022                NR
# 4      13    50293                 NR           5022                NR
#
#   organism_gender study_duration_mean exposure_duration_mean test_type  \
# 0              NR                   8                      8        NC
# 1              NR                   8                      8        NC
# 2              NR                   8                      8        NC
# 3              NR                   8                      8        NC
# 4              NR                   8                      8        NC
#
#   num_doses_mean  ... cas_number    chem_name formulation chemical_name  \
# ...

# %%
n = df.query('effect == "MOR"')

speciesMeasurement = n.groupby(['species', 'measurement']).size().sort_values(ascending=False)
speciesMeasurement
# Out:
# species        measurement
# norvegicus     GMOR/          60737
#                MORT           12841
# musculus       GMOR/          11758
# colchicus      GMOR/           5192
# norvegicus     SURV            5118
# platyrhynchos  GMOR/           4836
# terrestris     MORT            3808
# japonica       GMOR/           3542
# rubripes       GMOR/           3186
# musculus       MORT            2123
# esculentus     MORT            1813
# musculus       SURV            1648
# alba           GMOR/           1260
# candida        MORT            1174
# japonica       MORT            1084
# sp.            GMOR/           1052
# latrans        TDTH             918
# scrofa         MORT             882
# platyrhynchos  MORT             868
# andrei         GMOR/            814
# aries          MORT             701
# virginianus    MORT             689
# domesticus     GMOR/            654
# japonica       SURV             648
# sparverius     GMOR/            630
# ...
