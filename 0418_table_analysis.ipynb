# %% [markdown]
# # Analysis
#
# Creating relations between all columns with the effect measuments one to undestand their pattern and interference

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("../data/treated_data/table.txt", dtype='unicode')
df = df.drop(['line'], axis=1)
df.iloc[:5]
# Out:
#   test_id test_cas organism_lifestage species_number organism_age_mean  \
# 0      13    50293                 NR           5022                NR
# 1      13    50293                 NR           5022                NR
# 2      13    50293                 NR           5022                NR
# 3      13    50293                 NR           5022                NR
# 4      13    50293                 NR           5022                NR
#
#   organism_gender study_duration_mean exposure_duration_mean test_type  \
# 0              NR                   8                      8        NC
# 1              NR                   8                      8        NC
# 2              NR                   8                      8        NC
# 3              NR                   8                      8        NC
# 4              NR                   8                      8        NC
#
#   num_doses_mean  ... cas_number    chem_name formulation chemical_name  \
# 0              1  ...      67641  2-Propanone          NR   2-Propanone
# 1              1  ...      67641  2-Propanone          NR   2-Propanone
# 2              1  ...      67641  2-Propanone          NR   2-Propanone
# 3              1  ...      67641  2-Propanone          NR   2-Propanone
# 4              1  ...      67641  2-Propanone          NR   2-Propanone
#
#         common_name   kingdom        class    tax_order          family  \
# 0  Indian Earthworm  Animalia  Oligochaeta  Haplotaxida  Megascolecidae
# 1  Indian Earthworm  Animalia  Oligochaeta  Haplotaxida  Megascolecidae
# 2  Indian Earthworm  Animalia  Oligochaeta  Haplotaxida  Megascolecidae
# 3  Indian Earthworm  Animalia  Oligochaeta  Haplotaxida  Megascolecidae
# 4  Indian Earthworm  Animalia  Oligochaeta  Haplotaxida  Megascolecidae
#
#     species
# 0  posthuma
# 1  posthuma
# 2  posthuma
# 3  posthuma
# 4  posthuma
#
# [5 rows x 35 columns]

# %%
df.drop(df.loc[df['effect']!='MOR'].index, inplace=True)
df.iloc[:5]
# Out:
#      test_id  test_cas organism_lifestage species_number organism_age_mean  \
# 32     48691  10108642                 MA           5022                NR
# 33     48691  10108642                 MA           5022                NR
# 34     48691  10108642                 MA           5022                NR
# 35     48691  10108642                 MA           5022                NR
# 1206      50  32774166                 AD          28839                NR
#
#      organism_gender study_duration_mean exposure_duration_mean test_type  \
# 32                NR                  75                     NR        NC
# 33                NR                  75                     NR        NC
# 34                NR                  75                     NR        NC
# 35                NR                  75                     NR        NC
# 1206          Female                 135                    135        NC
#
#      num_doses_mean  ... cas_number    chem_name formulation chemical_name  \
# 32                4  ...    7732185        Water          NR         Water
# 33                4  ...    7732185        Water          NR         Water
# 34                4  ...    7732185        Water          NR         Water
# 35                4  ...    7732185        Water          NR         Water
# 1206              3  ...      67641  2-Propanone          NR   2-Propanone
#
#            common_name   kingdom        class    tax_order          family  \
# 32    Indian Earthworm  Animalia  Oligochaeta  Haplotaxida  Megascolecidae
# 33    Indian Earthworm  Animalia  Oligochaeta  Haplotaxida  Megascolecidae
# 34    Indian Earthworm  Animalia  Oligochaeta  Haplotaxida  Megascolecidae
# 35    Indian Earthworm  Animalia  Oligochaeta  Haplotaxida  Megascolecidae
# 1206     American Mink  Animalia     Mammalia    Carnivora      Mustelidae
#
#        species
# 32    posthuma
# 33    posthuma
# 34    posthuma
# 35    posthuma
# 1206     vison
#
# [5 rows x 35 columns]

# %% [markdown]
# Here we will try to get the relation of a specific value in the Species column with the effect Measument column

# %% [markdown]
# # Trying to create a filter
#
# The ideia is to understand how to create analysis betweet species and mortality

# %%
cols       = df.columns

table_cols = []
for c in cols.values:
    if c   != 'measurement':
        table_cols.append(c)

# %%
for c in table_cols:
    df.loc[df[c].isnull(),c] = 0
    
df.describe()
# Out:
#        test_id test_cas organism_lifestage species_number organism_age_mean  \
# count   134451   134451             134451         134451            134451
# unique    1542      347                 27            143                40
# top      53272    60571                 JV           4510                NR
# freq     16170    32210              74857          78737            101211
#
#        organism_gender study_duration_mean exposure_duration_mean test_type  \
# count           134451              134451                 134451    134451
# unique               4                  77                     77         2
# top               Both                  37                     36        NC
# freq            108613               52658                  51938    134428
#
#        num_doses_mean  ... cas_number chem_name formulation chemical_name  \
# count          134451  ...     134451    134451      134451        134451
# unique             13  ...         59        59           7            59
# top                 6  ...      64175   Ethanol          NR       Ethanol
# freq            64808  ...      59849     59849      133242         59849
#
#        common_name   kingdom     class  tax_order   family     species
# count       134451    134451    134451     134451   134451      134451
# unique         125         2        15         46       82         122
# top     Norway Rat  Animalia  Mammalia   Rodentia  Muridae  norvegicus
# freq         78737    132468     99057      96081    95948       78737
#
# [4 rows x 35 columns]

# %%
measurement_dict = df['measurement'].value_counts().to_dict()
measurement_dict
# Out:
# {'GMOR/': 93791,
#  'MORT': 29550,
#  'SURV': 9187,
#  'TDTH': 981,
#  'HTCH': 745,
#  'GMOR': 145,
#  'TKNO': 27,
#  'MDTH': 13,
#  'TLET': 6,
#  'SVVS': 5,
#  'LFSP': 1}

# %% [markdown]
# Recorrence number for all values in each column

# %%
value_counts_dict = {c: dict(df[c].value_counts()) for c in table_cols}
value_counts_dict
# Out:
# {'test_id': {'53272': 16170,
#   '53273': 15588,
#   '54831': 11344,
#   '53271': 9168,
#   '51856': 5016,
#   '53270': 4896,
#   '52849': 3600,
#   '53275': 3460,
#   '52848': 3006,
#   '2580': 2450,
#   '51743': 1890,
#   '53292': 1872,
#   '51857': 1872,
#   '52537': 1744,
#   '51855': 1653,
#   '53291': 1584,
#   '51858': 1548,
#   '53641': 1296,
#   '53110': 1290,
#   '53053': 1276,
#   '53269': 1232,
#   '54917': 1152,
#   '54916': 1152,
#   '54918': 1144,
#   '53111': 830,
#   '47414': 756,
#   '47412': 756,
#   '47411': 756,
#   '47413': 756,
#   '47415': 756,
#   '2110': 680,
#   '51883': 672,
#   '51650': 648,
#   '51748': 627,
#   '51139': 627,
#   '52525': 616,
#   '54934': 600,
#   '52374': 592,
#   '51884': 588,
#   '54935': 584,
#   '52380': 560,
#   '53276': 560,
#   '53112': 540,
#   '53108': 532,
#   '458': 492,
#   '49974': 485,
#   '53903': 480,
#   '53277': 468,
#   '52526': 459,
#   '53647': 456,
#   '49980': 396,
#   '49976': 392,
#   '49975': 392,
#   '53268': 390,
#   '52592': 384,
#   '52591': 384,
#   '52058': 368,
#   '266': 360,
#   '262': 360,
#   '46559': 350,
#   '50': 348,
#   '51870': 348,
#   '52350': 343,
#   '51831': 320,
#   '51871': 320,
#   '52373': 290,
#   '51869': 284,
#   '49929': 280,
#   '4979': 279,
#   '46570': 272,
#   '53143': 266,
#   '2111': 238,
#   '53107': 231,
#   '52575': 230,
#   '46808': 224,
#   '1813': 220,
#   '49928': 212,
#   '52909': 212,
#   '54933': 208,
#   '51939': 205,
#   '53050': 198,
#   '46807': 192,
#   '50798': 192,
#   '50799': 192,
#   '52375': 192,
#   '53020': 191,
#   '51867': 186,
#   '52574': 184,
#   '46569': 180,
#   '52351': 176,
#   '1811': 162,
#   '53630': 156,
#   '52132': 150,
#   '51475': 150,
#   '4584': 145,
#   '50797': 144,
#   '50796': 144,
#   '50837': 141,
#   '53632': 135,
#   '258': 135,
#   '52408': 130,
#   '49678': 124,
#   '272': 123,
#   '273': 123,
#   '271': 123,
#   '257': 120,
#   '49679': 120,
#   '261': 120,
#   '52843': 116,
#   '49794': 108,
#   '52348': 106,
#   '53649': 106,
#   '46437': 105,
#   '49948': 104,
#   '53628': 104,
#   '49981': 103,
#   '218': 99,
#   '52804': 99,
#   '52617': 98,
#   '49599': 98,
#   '52377': 98,
#   '2023': 96,
#   '50790': 96,
#   '52586': 93,
#   '54830': 90,
#   '54775': 85,
#   '46768': 80,
#   '51793': 80,
#   '270': 80,
#   '46762': 80,
#   '52569': 78,
#   '529': 78,
#   '54110': 76,
#   '54108': 76,
#   '54109': 72,
#   '52442': 72,
#   '45631': 72,
#   '2017': 72,
#   '54107': 72,
#   '436': 71,
#   '435': 71,
#   '434': 71,
#   '52523': 68,
#   '46812': 68,
#   '51808': 67,
#   '52805': 65,
#   '53631': 64,
#   '53646': 63,
#   '54720': 57,
#   '46244': 56,
#   '52078': 55,
#   '437': 55,
#   '52295': 55,
#   '51848': 52,
#   '52379': 50,
#   '51926': 50,
#   '51833': 48,
#   '2022': 48,
#   '53584': 46,
#   '46245': 44,
#   '51389': 44,
#   '51376': 44,
#   '51750': 44,
#   '51383': 44,
#   '51394': 44,
#   '51388': 44,
#   '51385': 44,
#   '51370': 44,
#   '51386': 44,
#   '51357': 44,
#   '51381': 44,
#   '51384': 44,
#   '51703': 44,
#   '51387': 44,
#   '51711': 44,
#   '51375': 44,
#   '51355': 44,
#   '51359': 44,
#   '51709': 44,
#   '51352': 44,
#   '51382': 44,
#   '51710': 44,
#   '51964': 41,
#   '54806': 39,
#   '50835': 38,
#   '52630': 38,
#   '52629': 38,
#   '53113': 36,
#   '51356': 36,
#   '51365': 34,
#   '51708': 34,
#   '51705': 34,
#   '51369': 34,
#   '4963': 33,
#   '52401': 32,
#   '12836': 32,
#   '12826': 32,
#   '46756': 32,
#   '52402': 32,
#   '52400': 32,
#   '46766': 32,
#   '4207': 32,
#   '53619': 31,
#   '45330': 30,
#   '1859': 30,
#   '1862': 30,
#   '1812': 30,
#   '2854': 30,
#   '2855': 30,
#   '52628': 30,
#   '1858': 30,
#   '1861': 30,
#   '52716': 30,
#   '1860': 30,
#   '53650': 29,
#   '47271': 26,
#   '3036': 26,
#   '51847': 24,
#   '1009': 24,
#   '53293': 24,
#   '50803': 23,
#   '46722': 21,
#   '46857': 20,
#   '2810': 20,
#   '2809': 20,
#   '46853': 20,
#   '46855': 20,
#   '51408': 19,
#   '46858': 19,
#   '49766': 18,
#   '51846': 17,
#   '52277': 17,
#   '51195': 17,
#   '5021': 16,
#   '57613': 16,
#   '50806': 16,
#   '2659': 16,
#   '2658': 16,
#   '52345': 16,
#   '2573': 16,
#   '53612': 16,
#   '53039': 15,
#   '54810': 15,
#   '53629': 14,
#   '4962': 14,
#   '50818': 13,
#   '49825': 13,
#   '506': 13,
#   '5025': 12,
#   '5026': 12,
#   '5020': 12,
#   '5024': 12,
#   '2867': 12,
#   '2660': 12,
#   '2661': 12,
#   '5022': 12,
#   '2657': 12,
#   '5028': 12,
#   '5029': 12,
#   '46514': 12,
#   '47569': 12,
#   '2662': 12,
#   '47270': 12,
#   '5031': 12,
#   '2663': 12,
#   '5027': 12,
#   '5030': 12,
#   '2664': 12,
#   '5023': 12,
#   '46515': 12,
#   '52727': 12,
#   '45373': 10,
#   '5296': 10,
#   '5261': 10,
#   '51671': 10,
#   '5305': 10,
#   '5298': 10,
#   '5289': 10,
#   '5271': 10,
#   '5303': 10,
#   '5285': 10,
#   '5258': 10,
#   '5302': 10,
#   '5340': 10,
#   '5264': 10,
#   '5297': 10,
#   '5332': 10,
#   '45374': 10,
#   '5328': 10,
#   '5349': 10,
#   '5330': 10,
#   '5269': 10,
#   '5270': 10,
#   '5279': 10,
#   '5277': 10,
#   '5281': 10,
#   '5347': 10,
#   '45379': 10,
#   '5260': 10,
#   '5319': 10,
#   '3060': 10,
#   '5351': 10,
#   '5262': 10,
#   '5265': 10,
#   '5345': 10,
#   '45376': 10,
#   '5324': 10,
#   '5267': 10,
#   '5294': 10,
#   '5291': 10,
#   '5278': 10,
#   '5306': 10,
#   '5307': 10,
#   '5287': 10,
#   '45381': 10,
#   '5259': 10,
#   '5326': 10,
#   '5329': 10,
#   '45378': 10,
#   '5276': 10,
#   '5286': 10,
#   '5333': 10,
#   '5341': 10,
#   '5318': 10,
#   '51669': 10,
#   '5301': 10,
#   '5255': 10,
#   '5327': 10,
#   '5312': 10,
#   '5272': 10,
#   '5284': 10,
#   '51672': 10,
#   '51192': 10,
#   '5346': 10,
#   '5344': 10,
#   '5317': 10,
#   '5295': 10,
#   '5288': 10,
#   '5348': 10,
#   '5320': 10,
#   '5325': 10,
#   '5292': 10,
#   '5335': 10,
#   '45371': 10,
#   '5308': 10,
#   '5256': 10,
#   '5321': 10,
#   '5280': 10,
#   '5263': 10,
#   '5322': 10,
#   '51670': 10,
#   '5352': 10,
#   '5290': 10,
#   '5299': 10,
#   '5300': 10,
#   '5282': 10,
#   '5309': 10,
#   '5310': 10,
#   '5268': 10,
#   '5316': 10,
#   '5311': 10,
#   '5313': 10,
#   '5339': 10,
#   '5315': 10,
#   '5293': 10,
#   '5314': 10,
#   '5266': 10,
#   '5283': 10,
#   '5273': 10,
#   '5343': 10,
#   '5338': 10,
#   '45377': 10,
#   '5350': 10,
#   '5331': 10,
#   '5304': 10,
#   '45375': 10,
#   '45372': 10,
#   '5323': 10,
#   '45370': 10,
#   '5334': 10,
#   '5254': 10,
#   '44864': 10,
#   '5274': 10,
#   '45380': 10,
#   '5336': 10,
#   '5342': 10,
#   '5337': 10,
#   '5275': 10,
#   '5257': 10,
#   '51789': 9,
#   '51193': 9,
#   '51643': 9,
#   '46792': 9,
#   '51194': 9,
#   '48586': 8,
#   '49791': 8,
#   '48588': 8,
#   '48587': 8,
#   '47541': 8,
#   '50836': 8,
#   '48581': 8,
#   '46243': 8,
#   '48585': 8,
#   '50102': 8,
#   '48584': 8,
#   '48589': 8,
#   '3061': 7,
#   '2811': 7,
#   '47273': 7,
#   '49822': 7,
#   '3062': 7,
#   '52419': 6,
#   '2672': 6,
#   '52417': 6,
#   '52415': 6,
#   '2997': 6,
#   '268': 6,
#   '2998': 6,
#   '46793': 6,
#   '49465': 5,
#   '45356': 5,
#   '48021': 5,
#   '54151': 5,
#   '46640': 5,
#   '45357': 5,
#   '51413': 5,
#   '49459': 5,
#   '49463': 5,
#   '55243': 4,
#   '49492': 4,
#   '53610': 4,
#   '47272': 4,
#   '52715': 4,
#   '47529': 4,
#   '55244': 4,
#   '48763': 4,
#   '55990': 4,
#   '49494': 4,
#   '49491': 4,
#   '52416': 4,
#   '49488': 4,
#   '52395': 4,
#   '48762': 4,
#   '46839': 4,
#   '52418': 4,
#   '47540': 4,
#   '49467': 4,
#   '52414': 4,
#   '49493': 4,
#   '50104': 4,
#   '55247': 4,
#   '48761': 4,
#   '55260': 4,
#   '55246': 4,
#   '2019': 4,
#   '48042': 4,
#   '51140': 4,
#   '55242': 4,
#   '49496': 4,
#   '55239': 4,
#   '48691': 4,
#   '55258': 4,
#   '46719': 4,
#   '2018': 4,
#   '49487': 4,
#   '49490': 4,
#   '55259': 4,
#   '49489': 4,
#   '49495': 4,
#   '45355': 3,
#   '57329': 3,
#   '51470': 3,
#   '53614': 3,
#   '54774': 3,
#   '57600': 3,
#   '52280': 3,
#   '423469': 3,
#   '57057': 3,
#   '4969': 3,
#   '49457': 3,
#   '57058': 3,
#   '49461': 3,
#   '45354': 3,
#   '53611': 3,
#   '4972': 3,
#   '57599': 3,
#   '53657': 2,
#   '4547': 2,
#   '53655': 2,
#   '53654': 2,
#   '53662': 2,
#   '53673': 2,
#   '53658': 2,
#   '50103': 2,
#   '4327': 2,
#   '51560': 2,
#   '53663': 2,
#   '56293': 2,
#   '4323': 2,
#   '4563': 2,
#   '53669': 2,
#   '53661': 2,
#   '53653': 2,
#   '4334': 2,
#   '53665': 2,
#   '55268': 2,
#   '4340': 2,
#   '53660': 2,
#   '53613': 2,
#   '53652': 2,
#   '53674': 2,
#   '4551': 2,
#   '4325': 2,
#   '51565': 2,
#   '4330': 2,
#   '53659': 2,
#   '4566': 2,
#   '4562': 2,
#   '51564': 2,
#   '51561': 2,
#   '55238': 2,
#   '55257': 2,
#   '55229': 2,
#   '4579': 2,
#   '53656': 2,
#   '55256': 2,
#   '4329': 2,
#   '4571': 2,
#   '4324': 2,
#   '4555': 2,
#   '53671': 2,
#   '409106': 2,
#   '4546': 2,
#   '4559': 2,
#   '4570': 2,
#   '53666': 2,
#   '4558': 2,
#   '53672': 2,
#   '4543': 2,
#   '4326': 2,
#   '409080': 2,
#   '55269': 2,
#   '4542': 2,
#   '57056': 2,
#   '4328': 2,
#   '4554': 2,
#   '53667': 2,
#   '4331': 2,
#   '53664': 2,
#   '4567': 2,
#   '55255': 2,
#   '55270': 2,
#   '53670': 2,
#   '4575': 2,
#   '55230': 2,
#   '53668': 2,
#   '4333': 2,
#   '56292': 2,
#   '4578': 2,
#   '4550': 2,
#   '4332': 2,
#   '4322': 2,
#   '4341': 2,
#   '505937': 1,
#   '527515': 1,
#   '550797': 1,
#   '522912': 1,
#   '572061': 1,
#   '511808': 1,
#   '538504': 1,
#   '573978': 1,
#   '550995': 1,
#   '538259': 1,
#   '578853': 1,
#   '562341': 1,
#   '567401': 1,
#   '578877': 1,
#   '579030': 1,
#   '550788': 1,
#   '451230': 1,
#   '450380': 1,
#   '556724': 1,
#   '586971': 1,
#   '441442': 1,
#   '564455': 1,
#   '550846': 1,
#   '512857': 1,
#   '550809': 1,
#   '464996': 1,
#   '556684': 1,
#   '511797': 1,
#   '524228': 1,
#   '550719': 1,
#   '512876': 1,
#   '443801': 1,
#   '541792': 1,
#   '556721': 1,
#   '539246': 1,
#   '512710': 1,
#   '532111': 1,
#   '550981': 1,
#   '578627': 1,
#   '517943': 1,
#   '550773': 1,
#   '565946': 1,
#   '539590': 1,
#   '550755': 1,
#   '517914': 1,
#   '535005': 1,
#   '550933': 1,
#   '550934': 1,
#   '507743': 1,
#   '572146': 1,
#   '527492': 1,
#   '519248': 1,
#   '517955': 1,
#   '554844': 1,
#   '550712': 1,
#   '579186': 1,
#   '536558': 1,
#   '517915': 1,
#   '4318': 1,
#   '550945': 1,
#   '578881': 1,
#   '550774': 1,
#   '578892': 1,
#   '550992': 1,
#   '515955': 1,
#   '518464': 1,
#   '524217': 1,
#   '550957': 1,
#   '579130': 1,
#   '541788': 1,
#   '578885': 1,
#   '550739': 1,
#   '54454': 1,
#   '550661': 1,
#   '534994': 1,
#   '505971': 1,
#   '443856': 1,
#   '527508': 1,
#   '512653': 1,
#   '591219': 1,
#   '475249': 1,
#   '564633': 1,
#   '550899': 1,
#   '550860': 1,
#   '512650': 1,
#   '533802': 1,
#   '511278': 1,
#   '564520': 1,
#   '505942': 1,
#   '550647': 1,
#   '474268': 1,
#   '550686': 1,
#   '562756': 1,
#   '487065': 1,
#   '578873': 1,
#   '578838': 1,
#   '517957': 1,
#   '523632': 1,
#   '4313': 1,
#   '550870': 1,
#   '521481': 1,
#   '54284': 1,
#   '520113': 1,
#   '538266': 1,
#   '551031': 1,
#   '551033': 1,
#   '517870': 1,
#   '505948': 1,
#   '579127': 1,
#   '547235': 1,
#   '550912': 1,
#   '443788': 1,
#   '578895': 1,
#   '550769': 1,
#   '580510': 1,
#   '565720': 1,
#   '550911': 1,
#   '519255': 1,
#   '532124': 1,
#   '520107': 1,
#   '53773': 1,
#   '578674': 1,
#   '443868': 1,
#   '49803': 1,
#   '511798': 1,
#   '517902': 1,
#   '513484': 1,
#   '538511': 1,
#   '578862': 1,
#   '520122': 1,
#   '538252': 1,
#   '556670': 1,
#   '564428': 1,
#   '427827': 1,
#   '505968': 1,
#   '522979': 1,
#   '444952': 1,
#   '550734': 1,
#   '534992': 1,
#   '578858': 1,
#   '538507': 1,
#   '520125': 1,
#   '523629': 1,
#   '520106': 1,
#   '517868': 1,
#   '579099': 1,
#   '578851': 1,
#   '550823': 1,
#   '550922': 1,
#   '491969': 1,
#   '474003': 1,
#   '535009': 1,
#   '559939': 1,
#   '517913': 1,
#   '578896': 1,
#   '550745': 1,
#   '573937': 1,
#   '572099': 1,
#   '562656': 1,
#   '443762': 1,
#   '527502': 1,
#   '527486': 1,
#   '513512': 1,
#   '578998': 1,
#   '578870': 1,
#   '428583': 1,
#   '512695': 1,
#   '562311': 1,
#   '550975': 1,
#   '550994': 1,
#   '517967': 1,
#   '520110': 1,
#   '578876': 1,
#   '542502': 1,
#   '443775': 1,
#   '578854': 1,
#   '535002': 1,
#   '57535': 1,
#   '475255': 1,
#   '578867': 1,
#   '550784': 1,
#   '450382': 1,
#   '536557': 1,
#   '550932': 1,
#   '53791': 1,
#   '51466': 1,
#   '572141': 1,
#   '53990': 1,
#   '547228': 1,
#   '520128': 1,
#   '579025': 1,
#   '450383': 1,
#   '538467': 1,
#   '49827': 1,
#   '565713': 1,
#   '554841': 1,
#   '550715': 1,
#   '550993': 1,
#   '550653': 1,
#   '516098': 1,
#   '518916': 1,
#   '474278': 1,
#   '564413': 1,
#   '578880': 1,
#   '572138': 1,
#   '4319': 1,
#   '572124': 1,
#   '423497': 1,
#   '579113': 1,
#   '536551': 1,
#   '567030': 1,
#   '566811': 1,
#   '578878': 1,
#   '469419': 1,
#   '578848': 1,
#   '537000': 1,
#   '533862': 1,
#   '432335': 1,
#   '550931': 1,
#   '517959': 1,
#   '522976': 1,
#   '517916': 1,
#   '550861': 1,
#   '432283': 1,
#   '465005': 1,
#   '517908': 1,
#   '572144': 1,
#   '57567': 1,
#   '572086': 1,
#   '524225': 1,
#   '535003': 1,
#   '517949': 1,
#   '562721': 1,
#   '551032': 1,
#   '517917': 1,
#   '536565': 1,
#   '550817': 1,
#   '532108': 1,
#   '564596': 1,
#   '572073': 1,
#   '512679': 1,
#   '57565': 1,
#   '527512': 1,
#   '553505': 1,
#   '572102': 1,
#   '550754': 1,
#   '550921': 1,
#   '511806': 1,
#   '578850': 1,
#   '2804': 1,
#   '519237': 1,
#   '512411': 1,
#   '429619': 1,
#   '520103': 1,
#   '524231': 1,
#   '550694': 1,
#   '512680': 1,
#   '556176': 1,
#   '550713': 1,
#   '511277': 1,
#   '550943': 1,
#   '572104': 1,
#   '550893': 1,
#   '550844': 1,
#   '556704': 1,
#   '550761': 1,
#   '550801': 1,
#   '429611': 1,
#   '57538': 1,
#   '578902': 1,
#   '532135': 1,
#   '556755': 1,
#   '518473': 1,
#   '511786': 1,
#   '579077': 1,
#   '561684': 1,
#   '578900': 1,
#   '550930': 1,
#   '512678': 1,
#   '511784': 1,
#   '51464': 1,
#   '534990': 1,
#   '505922': 1,
#   '519267': 1,
#   '491972': 1,
#   '551024': 1,
#   '519236': 1,
#   '564627': 1,
#   '551017': 1,
#   '534979': 1,
#   '551023': 1,
#   '429386': 1,
#   '505920': 1,
#   '522932': 1,
#   '556712': 1,
#   '517880': 1,
#   '579116': 1,
#   '491958': 1,
#   '579194': 1,
#   '512697': 1,
#   '535000': 1,
#   '512700': 1,
#   '578864': 1,
#   '534999': 1,
#   '550965': 1,
#   '520108': 1,
#   '578840': 1,
#   '518458': 1,
#   '513490': 1,
#   '524200': 1,
#   '464995': 1,
#   '572093': 1,
#   '520126': 1,
#   '474010': 1,
#   '53781': 1,
#   '554857': 1,
#   '446733': 1,
#   '536553': 1,
#   '535015': 1,
#   '551016': 1,
#   '556718': 1,
#   '512704': 1,
#   '578890': 1,
#   '523626': 1,
#   '556759': 1,
#   '572142': 1,
#   '494566': 1,
#   '511718': 1,
#   '561654': 1,
#   '450384': 1,
#   '539341': 1,
#   '572159': 1,
#   '428581': 1,
#   '564602': 1,
#   '564786': 1,
#   '517901': 1,
#   '579042': 1,
#   '556763': 1,
#   '550762': 1,
#   '572135': 1,
#   '579136': 1,
#   '556175': 1,
#   '567050': 1,
#   '576873': 1,
#   '538461': 1,
#   '535013': 1,
#   '550948': 1,
#   '578871': 1,
#   '550839': 1,
#   '445918': 1,
#   '520120': 1,
#   '526857': 1,
#   '511805': 1,
#   '57566': 1,
#   '431576': 1,
#   '524226': 1,
#   '578839': 1,
#   '556679': 1,
#   '561700': 1,
#   '428585': 1,
#   '559938': 1,
#   '520115': 1,
#   '535012': 1,
#   '578875': 1,
#   '53775': 1,
#   '550838': 1,
#   '578689': 1,
#   '551013': 1,
#   '551011': 1,
#   '57536': 1,
#   '550787': 1,
#   '556720': 1,
#   '556173': 1,
#   '423498': 1,
#   '561690': 1,
#   '556715': 1,
#   '564606': 1,
#   '572130': 1,
#   '522913': 1,
#   '465000': 1,
#   '572120': 1,
#   '578863': 1,
#   '534982': 1,
#   '520124': 1,
#   '429623': 1,
#   '550984': 1,
#   '550785': 1,
#   '505970': 1,
#   '524201': 1,
#   '550929': 1,
#   '578866': 1,
#   '517224': 1,
#   '515946': 1,
#   '572119': 1,
#   '562726': 1,
#   '427899': 1,
#   '535007': 1,
#   '578874': 1,
#   '534991': 1,
#   '554846': 1,
#   '451233': 1,
#   '578602': 1,
#   '572067': 1,
#   '515967': 1,
#   '550973': 1,
#   '427822': 1,
#   '579090': 1,
#   '524227': 1,
#   '428586': 1,
#   '578893': 1,
#   '550697': 1,
#   '594076': 1,
#   '446743': 1,
#   '550988': 1,
#   '550983': 1,
#   '562731': 1,
#   '579049': 1,
#   '520129': 1,
#   '522982': 1,
#   '564534': 1,
#   '522981': 1,
#   '520105': 1,
#   '520123': 1,
#   '550935': 1,
#   '535016': 1,
#   '431568': 1,
#   '519227': 1,
#   '550718': 1,
#   '511839': 1,
#   '550913': 1,
#   '572098': 1,
#   '523631': 1,
#   '579181': 1,
#   '4508': 1,
#   '512698': 1,
#   '550725': 1,
#   '517898': 1,
#   ...},
#  'test_cas': {'60571': 32210,
#   '50293': 29109,
#   '309002': 27232,
#   '70304': 5033,
#   '72559': 4380,
#   '87683': 2450,
#   '28300745': 2374,
#   '118967': 2247,
#   '11097691': 1923,
#   '10141001': 1890,
#   '1162658': 1872,
#   '10361372': 1744,
#   '301042': 1700,
#   '56531': 1592,
#   '72548': 1159,
#   '2921882': 1102,
#   '32598133': 1072,
#   '26538443': 1061,
#   '72208': 942,
#   '82666': 918,
#   '2385855': 846,
#   '56382': 831,
#   '63252': 830,
#   '7646799': 627,
#   '7778509': 516,
#   '115322': 481,
#   '32774166': 348,
#   '87865': 342,
#   '7439921': 341,
#   '10108642': 292,
#   '58899': 274,
#   '79072': 272,
#   '121824': 260,
#   '8001352': 255,
#   '13366739': 246,
#   '121755': 178,
#   '35367385': 151,
#   '1746016': 151,
#   '7779886': 145,
#   '57749': 135,
#   '10099748': 129,
#   '298000': 121,
#   '7786814': 117,
#   '50328': 107,
#   '7487947': 104,
#   '1330207': 104,
#   '1563662': 101,
#   '79061': 99,
#   '78308324': 96,
#   '333415': 91,
#   '10453868': 82,
#   '77474': 80,
#   '6080564': 80,
#   '114261': 79,
#   '52645531': 78,
#   '40596698': 76,
#   '1317368': 65,
#   '16752775': 59,
#   '10124364': 59,
#   '22967926': 58,
#   '3251238': 52,
#   '298022': 52,
#   '298044': 51,
#   '7758987': 51,
#   '143500': 50,
#   '108883': 46,
#   '52918635': 46,
#   '144218': 45,
#   '76448': 44,
#   '58220': 44,
#   '29232937': 44,
#   '6369591': 44,
#   '54115': 44,
#   '129793': 44,
#   '9004675': 44,
#   '7440439': 44,
#   '93765': 44,
#   '108383': 44,
#   '71432': 44,
#   '13410010': 44,
#   '81072': 44,
#   '57410': 44,
#   '530507': 44,
#   '108941': 44,
#   '55981': 44,
#   '52315078': 44,
#   '116063': 44,
#   '315184': 44,
#   '632213': 44,
#   '79005': 44,
#   '64857': 44,
#   '944229': 42,
#   '12789036': 42,
#   '122145': 42,
#   '16960397': 41,
#   '297789': 41,
#   '470906': 41,
#   '115902': 41,
#   '327980': 41,
#   '297972': 40,
#   '8065369': 40,
#   '2984647': 40,
#   '789026': 39,
#   '26002802': 39,
#   '133062': 38,
#   '50180': 36,
#   '10325947': 36,
#   '50442': 34,
#   '305033': 34,
#   '86500': 34,
#   '11103574': 34,
#   '59052': 34,
#   '517168': 30,
#   '51630581': 30,
#   '17804352': 29,
#   '7786347': 26,
#   '23564058': 24,
#   '120127': 24,
#   '7718549': 20,
#   '72280525': 18,
#   '74051802': 18,
#   '72131807': 18,
#   '115093': 16,
#   '6923224': 16,
#   '23031369': 14,
#   '10102188': 14,
#   '7784410': 13,
#   '68359375': 13,
#   '563122': 13,
#   '39515418': 13,
#   '1912249': 13,
#   '52686': 13,
#   '12680487': 12,
#   '115297': 12,
#   '39515407': 11,
#   '33089611': 10,
#   '87821': 10,
#   '2234131': 10,
#   '60515': 10,
#   '35065271': 10,
#   '54406483': 9,
#   '15708415': 9,
#   '71756199': 9,
#   '107534963': 9,
#   '56578337': 8,
#   '2691410': 8,
#   '129000': 8,
#   '85018': 8,
#   '61949766': 7,
#   '94757': 7,
#   '1332407': 7,
#   '3813147': 7,
#   '69409945': 7,
#   '55389': 6,
#   '10265926': 6,
#   '7646857': 6,
#   '110735949': 6,
#   '66841267': 6,
#   '161050584': 6,
#   '11141176': 6,
#   '72588842': 6,
#   '311455': 5,
#   '8003347': 5,
#   '133073': 4,
#   '51026289': 4,
#   '150685': 4,
#   '60207901': 4,
#   '104405': 4,
#   '7775099': 4,
#   '36734197': 4,
#   '2310170': 4,
#   '3383968': 4,
#   '608731': 4,
#   '11096825': 4,
#   '91465086': 4,
#   '1910425': 4,
#   '107028': 4,
#   '61949777': 4,
#   '1773371': 3,
#   '71751412': 3,
#   '2104645': 3,
#   '370865': 3,
#   '118741': 3,
#   '20018091': 3,
#   '300765': 3,
#   '999815': 3,
#   '6164983': 3,
#   '7733020': 3,
#   '117817': 3,
#   '330552': 3,
#   '950378': 3,
#   '90153': 3,
#   '51285': 3,
#   '562743': 3,
#   '8002651': 3,
#   '66996109': 2,
#   '72542564': 2,
#   '72542611': 2,
#   '76222': 2,
#   '71756008': 2,
#   '962583': 2,
#   '91203': 2,
#   '8020835': 2,
#   '137304': 2,
#   '89838': 2,
#   '76879': 2,
#   '71756100': 2,
#   '57067': 2,
#   '78488': 2,
#   '9002931': 2,
#   '127902': 2,
#   '62697921': 2,
#   '1490046': 2,
#   '140114': 2,
#   '2588036': 2,
#   '138863': 2,
#   '470826': 2,
#   '30560191': 2,
#   '122349': 2,
#   '552307': 2,
#   '2588047': 2,
#   '2439103': 2,
#   '5598130': 2,
#   '149304': 2,
#   '591877': 2,
#   '98555': 2,
#   '68085858': 2,
#   '62748': 2,
#   '41198087': 2,
#   '100516': 2,
#   '14816183': 2,
#   '71747074': 2,
#   '24017478': 1,
#   '79107': 1,
#   '144627': 1,
#   '100027': 1,
#   '142621': 1,
#   '21259201': 1,
#   '3424826': 1,
#   '19750959': 1,
#   '10311849': 1,
#   '4371522': 1,
#   '115866': 1,
#   '188023861': 1,
#   '59870': 1,
#   '108394': 1,
#   '28839498': 1,
#   '7553562': 1,
#   '89662306': 1,
#   '111148': 1,
#   '131113': 1,
#   '148798': 1,
#   '39765805': 1,
#   '64471': 1,
#   '32534819': 1,
#   '7440666': 1,
#   '104767': 1,
#   '2255176': 1,
#   '115970177': 1,
#   '121697': 1,
#   '4180238': 1,
#   '26628228': 1,
#   '20859738': 1,
#   '330541': 1,
#   '112732': 1,
#   '57636': 1,
#   '7772998': 1,
#   '72435': 1,
#   '118525': 1,
#   '83794': 1,
#   '117148057': 1,
#   '97530': 1,
#   '84695': 1,
#   '53963': 1,
#   '87514': 1,
#   '2425061': 1,
#   '106230': 1,
#   '78875': 1,
#   '635223': 1,
#   '5326238': 1,
#   '100016': 1,
#   '101724': 1,
#   '120868668': 1,
#   '84662': 1,
#   '11100144': 1,
#   '64902723': 1,
#   '69352905': 1,
#   '108429': 1,
#   '13311847': 1,
#   '82657043': 1,
#   '111831': 1,
#   '119368': 1,
#   '499752': 1,
#   '70124775': 1,
#   '57249': 1,
#   '121211': 1,
#   '97778': 1,
#   '1314847': 1,
#   '88857': 1,
#   '7447394': 1,
#   '756796': 1,
#   '25954136': 1,
#   '2510863': 1,
#   '82451': 1,
#   '28434006': 1,
#   '4376209': 1,
#   '84742': 1,
#   '115086549': 1,
#   '95807': 1,
#   '50471448': 1,
#   '51338273': 1,
#   '121142': 1,
#   '104552': 1,
#   '107186': 1,
#   '538238': 1,
#   '2021218': 1,
#   '138261413': 1,
#   '64186': 1,
#   '84753': 1,
#   '137268': 1,
#   '24519855': 1,
#   '107051': 1,
#   '80844071': 1,
#   '91178': 1,
#   '3244904': 1,
#   '26445012': 1,
#   '141662': 1,
#   '10482561': 1,
#   '85405': 1,
#   '479130': 1,
#   '109524': 1,
#   '1746812': 1,
#   '112050': 1,
#   '112345': 1,
#   '34419051': 1,
#   '59518': 1,
#   '51036': 1,
#   '54578299': 1,
#   '62533': 1,
#   '3337700': 1,
#   '60128': 1,
#   '7447418': 1,
#   '104541': 1,
#   '89827': 1,
#   '64175': 1,
#   '3337711': 1,
#   '700061': 1},
#  'organism_lifestage': {'JV': 74857,
#   'NR': 32472,
#   'AD': 9686,
#   'MA': 5003,
#   'GE': 4499,
#   'SM': 3623,
#   'TU': 1768,
#   'LV': 1398,
#   'YE': 643,
#   'YO': 143,
#   'MX': 89,
#   'SD': 83,
#   'EM': 58,
#   'NY': 30,
#   'SL': 25,
#   'PU': 19,
#   'EG': 15,
#   'SA': 10,
#   'CC': 8,
#   'NH': 6,
#   'YA': 5,
#   'LC': 4,
#   'IM': 2,
#   'VI': 2,
#   'NB': 1,
#   'OO': 1,
#   'NE': 1},
#  'species_number': {'4510': 78737,
#   '4913': 15544,
#   '2994': 5882,
#   '4435': 4658,
#   '4437': 4180,
#   '5004': 3808,
#   '4441': 3186,
#   '3384': 1813,
#   '7316': 1398,
#   '4527': 1260,
#   '16312': 1184,
#   '11147': 1140,
#   '7588': 952,
#   '4451': 919,
#   '4946': 882,
#   '4471': 849,
#   '4997': 802,
#   '4991': 792,
#   '5017': 701,
#   '4456': 673,
#   '10913': 632,
#   '7654': 416,
#   '4516': 370,
#   '28839': 348,
#   '4910': 318,
#   '397': 296,
#   '16311': 208,
#   '5990': 180,
#   '11193': 145,
#   '4988': 130,
#   '5003': 109,
#   '7301': 106,
#   '4486': 104,
#   '4491': 101,
#   '5064': 98,
#   '4975': 84,
#   '3477': 83,
#   '11154': 80,
#   '2422': 63,
#   '16654': 60,
#   '16652': 59,
#   '4474': 57,
#   '3413': 54,
#   '4911': 48,
#   '19831': 41,
#   '10256': 40,
#   '19522': 39,
#   '19765': 39,
#   '7569': 38,
#   '11975': 36,
#   '18123': 36,
#   '4457': 31,
#   '230': 31,
#   '7384': 30,
#   '4524': 28,
#   '16735': 26,
#   '3581': 24,
#   '16679': 20,
#   '10978': 18,
#   '19544': 18,
#   '10457': 16,
#   '5024': 16,
#   '4490': 16,
#   '10384': 15,
#   '5422': 15,
#   '1077': 14,
#   '4907': 13,
#   '358': 13,
#   '1418': 12,
#   '10622': 12,
#   '19543': 11,
#   '7586': 11,
#   '5009': 11,
#   '15908': 11,
#   '11533': 11,
#   '16036': 9,
#   '5541': 9,
#   '5204': 9,
#   '4507': 8,
#   '20473': 8,
#   '17889': 8,
#   '16846': 8,
#   '10931': 8,
#   '4914': 7,
#   '17490': 7,
#   '4550': 7,
#   '206': 7,
#   '625': 6,
#   '10403': 6,
#   '16256': 6,
#   '5098': 5,
#   '812': 5,
#   '5760': 5,
#   '4976': 5,
#   '4916': 4,
#   '18352': 4,
#   '971': 4,
#   '16738': 4,
#   '20298': 4,
#   '18998': 4,
#   '5022': 4,
#   '4489': 4,
#   '18180': 4,
#   '1049': 4,
#   '16038': 4,
#   '5731': 4,
#   '5061': 4,
#   '11711': 3,
#   '12619': 3,
#   '16776': 3,
#   '19685': 3,
#   '18108': 3,
#   '16677': 3,
#   '1847': 3,
#   '4928': 3,
#   '3582': 2,
#   '4912': 2,
#   '9284': 2,
#   '5085': 2,
#   '4495': 2,
#   '5084': 2,
#   '16676': 2,
#   '4111': 2,
#   '16304': 2,
#   '5519': 2,
#   '16837': 2,
#   '17605': 2,
#   '17151': 2,
#   '4438': 1,
#   '10085': 1,
#   '10472': 1,
#   '20001': 1,
#   '27849': 1,
#   '3810': 1,
#   '16873': 1,
#   '4917': 1,
#   '4501': 1,
#   '3885': 1,
#   '3275': 1,
#   '7305': 1,
#   '24945': 1,
#   '2355': 1,
#   '11439': 1},
#  'organism_age_mean': {'NR': 101211,
#   '5': 10180,
#   '28': 6606,
#   '1': 5073,
#   '6': 3021,
#   '2.5': 2450,
#   '2': 1294,
#   '3': 678,
#   '7': 652,
#   '4': 636,
#   '21': 565,
#   '14': 476,
#   '8': 349,
#   '10': 328,
#   '20': 168,
#   '12': 135,
#   '50': 124,
#   '9': 113,
#   '55': 90,
#   '19': 64,
#   '24': 57,
#   '0': 48,
#   '18': 41,
#   '15': 25,
#   '16': 20,
#   '42': 15,
#   '13': 9,
#   '120': 5,
#   '17': 3,
#   '60': 3,
#   '65': 2,
#   '51': 2,
#   '79': 1,
#   '9.5': 1,
#   '46': 1,
#   '57': 1,
#   '47': 1,
#   '48': 1,
#   '39': 1,
#   '61': 1},
#  'organism_gender': {'Both': 108613,
#   'NR': 12719,
#   'Female': 10641,
#   'Male': 2478},
#  'study_duration_mean': {'37': 52658,
#   'NR': 12233,
#   '6': 11470,
#   '8': 10095,
#   '2': 6336,
#   '90': 4299,
#   '10': 4289,
#   '14': 2965,
#   '36': 2664,
#   '21': 2508,
#   '20': 2324,
#   '13': 2244,
#   '24': 2201,
#   '45': 1768,
#   '187': 1296,
#   '16': 1277,
#   '170': 1184,
#   '15': 1047,
#   '343': 924,
#   'NC': 912,
#   '35': 817,
#   '56': 802,
#   '12': 703,
#   '34': 629,
#   '22': 554,
#   '112': 439,
#   '96': 416,
#   '83': 348,
#   '135': 348,
#   '11': 330,
#   '4': 323,
#   '42': 302,
#   '168': 288,
#   '89': 279,
#   '210': 260,
#   '120': 220,
#   '9': 208,
#   '3': 202,
#   '40': 200,
#   '128': 135,
#   '133': 135,
#   '7': 128,
#   '28': 127,
#   '5': 126,
#   '129': 124,
#   '60': 113,
#   '23': 101,
#   '39': 98,
#   '58': 98,
#   '64': 80,
#   '28.0': 76,
#   '29.6': 76,
#   '29': 72,
#   '25.7': 72,
#   '31.7': 72,
#   '32': 68,
#   '84': 64,
#   '268': 39,
#   '73': 38,
#   '6.5': 35,
#   '462': 26,
#   '27': 23,
#   '30': 23,
#   '48': 21,
#   '95': 18,
#   '77': 16,
#   '364': 14,
#   '98': 13,
#   '19': 12,
#   '67': 12,
#   '72': 9,
#   '17': 7,
#   '31': 6,
#   '75': 4,
#   '1': 3,
#   '228': 3,
#   '103': 2},
#  'exposure_duration_mean': {'36': 51938,
#   '6': 15285,
#   '8': 11037,
#   'NR': 9926,
#   '13': 5904,
#   '2': 5885,
#   '10': 4857,
#   '90': 4561,
#   '24': 2475,
#   '16': 2472,
#   '14': 2407,
#   '45': 1770,
#   '135': 1644,
#   '17': 1591,
#   '34': 1178,
#   '21': 965,
#   '343': 924,
#   '12': 917,
#   '35': 860,
#   '37': 727,
#   '11': 644,
#   '170': 600,
#   '168': 548,
#   '20': 486,
#   '4': 473,
#   '112': 439,
#   '96': 416,
#   '83': 348,
#   '42': 323,
#   0: 314,
#   '89': 279,
#   '9': 220,
#   '3': 218,
#   '40': 208,
#   '7': 149,
#   '5': 149,
#   '18': 148,
#   '120': 140,
#   '133': 135,
#   '28': 135,
#   '60': 123,
#   '23': 96,
#   '48': 79,
#   '32': 68,
#   '84': 64,
#   '1': 47,
#   '268': 39,
#   '72': 34,
#   '30': 26,
#   '27': 23,
#   '29': 21,
#   '53': 18,
#   '76': 16,
#   '364': 14,
#   '19': 13,
#   '98': 13,
#   '67': 12,
#   '70': 8,
#   '360': 6,
#   '31': 4,
#   '65': 4,
#   '80': 4,
#   '228': 3,
#   '22': 3,
#   '25': 2,
#   '100': 2,
#   '50': 2,
#   '103': 2,
#   '420': 2,
#   '85': 1,
#   '75': 1,
#   '111': 1,
#   '44': 1,
#   '130': 1,
#   '515': 1,
#   '55': 1,
#   '56': 1},
#  'test_type': {'NC': 134428, 'NR': 23},
#  'num_doses_mean': {'6': 64808,
#   '5': 28015,
#   '2': 11065,
#   '4': 10532,
#   '3': 9973,
#   '7': 6665,
#   '9': 1387,
#   '8': 882,
#   '10': 651,
#   '1': 383,
#   'NR': 51,
#   '12': 38,
#   '11': 1},
#  'application_freq_mean': {'NR': 113898,
#   '1': 12122,
#   '16': 3456,
#   '5': 1297,
#   '3': 1277,
#   '6': 882,
#   '12': 488,
#   '9': 414,
#   '10': 351,
#   '30': 161,
#   '2': 41,
#   '8': 29,
#   0: 16,
#   '4': 11,
#   '7': 2,
#   '28': 1,
#   '19': 1,
#   '11': 1,
#   '240': 1,
#   '84': 1,
#   '13': 1},
#  'halflife_mean': {'NC': 134451},
#  'result_id': {'1233166': 16170,
#   '1233169': 15588,
#   '1187765': 11344,
#   '1233163': 9168,
#   '1228385': 5016,
#   '1233160': 4896,
#   '1233153': 3600,
#   '1233172': 3460,
#   '1233150': 3006,
#   '1185657': 2450,
#   '1228162': 1890,
#   '1228388': 1872,
#   '1184106': 1872,
#   '1233423': 1744,
#   '1228381': 1653,
#   '1184099': 1584,
#   '1228391': 1548,
#   '1187142': 1296,
#   '1231984': 1290,
#   '1234231': 1276,
#   '1233157': 1232,
#   '1188277': 1152,
#   '1188280': 1152,
#   '1188283': 1144,
#   '1231987': 830,
#   '1189842': 756,
#   '1189844': 756,
#   '1189845': 756,
#   '1189846': 756,
#   '1189843': 756,
#   '1185345': 680,
#   '1187230': 672,
#   '1186721': 648,
#   '1232739': 627,
#   '1223099': 627,
#   '1234726': 616,
#   '1229953': 600,
#   '1230588': 592,
#   '1187234': 588,
#   '1229957': 584,
#   '1233176': 560,
#   '1232826': 560,
#   '1231990': 540,
#   '1231974': 532,
#   '1184293': 492,
#   '1230782': 485,
#   '1188266': 480,
#   '1233178': 468,
#   '1234731': 459,
#   '1182927': 456,
#   '1230791': 396,
#   '1230785': 392,
#   '1230788': 392,
#   '1233156': 390,
#   '1233186': 384,
#   '1233183': 384,
#   '1188273': 368,
#   '1183955': 360,
#   '1183950': 360,
#   '1224196': 350,
#   '1183467': 348,
#   '1186619': 348,
#   '1186125': 343,
#   '1186625': 320,
#   '1186608': 320,
#   '1230584': 290,
#   '1186614': 284,
#   '1186156': 280,
#   '1188617': 279,
#   '1224204': 272,
#   '1231977': 266,
#   '1185347': 238,
#   '1231971': 231,
#   '1228123': 230,
#   '1189858': 224,
#   '1184889': 220,
#   '1188261': 212,
#   '1186151': 212,
#   '1231154': 208,
#   '1228100': 205,
#   '1234210': 198,
#   '1187418': 192,
#   '1232812': 192,
#   '1187423': 192,
#   '1189857': 192,
#   '1227308': 191,
#   '1188403': 186,
#   '1228118': 184,
#   '1224200': 180,
#   '1186129': 176,
#   '1184884': 162,
#   '1187468': 156,
#   '1186198': 150,
#   '1186902': 150,
#   '1188588': 145,
#   '1187408': 144,
#   '1187413': 144,
#   '1188153': 141,
#   '1183931': 135,
#   '1186318': 135,
#   '1234039': 130,
#   '1228669': 124,
#   '1184000': 123,
#   '1183996': 123,
#   '1183992': 123,
#   '1184004': 120,
#   '1183947': 120,
#   '1183926': 120,
#   '1186637': 116,
#   '1188409': 108,
#   '1188060': 106,
#   '1231057': 106,
#   '1220558': 105,
#   '1187456': 104,
#   '1184981': 104,
#   '1230794': 103,
#   '1183836': 99,
#   '1234315': 99,
#   '1232816': 98,
#   '1188391': 98,
#   '1186377': 98,
#   '1184982': 96,
#   '1185154': 96,
#   '1186664': 93,
#   '1231111': 90,
#   '1187680': 85,
#   '1186135': 80,
#   '1184173': 80,
#   '1183988': 80,
#   '1184179': 80,
#   '1184296': 78,
#   '1184457': 78,
#   '1235655': 76,
#   '1235645': 76,
#   '1233985': 72,
#   '1235640': 72,
#   '1221941': 72,
#   '1235650': 72,
#   '1185142': 72,
#   '1184220': 71,
#   '1184215': 71,
#   '1184210': 71,
#   '1234710': 68,
#   '1188995': 68,
#   '1230759': 67,
#   '1234321': 65,
#   '1186312': 64,
#   '1182924': 63,
#   '1227516': 57,
#   '1223842': 56,
#   '1186697': 55,
#   '1184224': 55,
#   '1188286': 55,
#   '1230300': 52,
#   '1230306': 50,
#   '1232821': 50,
#   '1230287': 48,
#   '1185152': 48,
#   '1231047': 46,
#   '1228611': 44,
#   '1228560': 44,
#   '1228554': 44,
#   '1228548': 44,
#   '1228509': 44,
#   '1228551': 44,
#   '1228563': 44,
#   '1228557': 44,
#   '1228524': 44,
#   '1228527': 44,
#   '1228476': 44,
#   '1228545': 44,
#   '1228464': 44,
#   '1228581': 44,
#   '1228617': 44,
#   '1223844': 44,
#   '1228566': 44,
#   '1228455': 44,
#   '1228614': 44,
#   '1228608': 44,
#   '1228470': 44,
#   '1228590': 44,
#   '1228542': 44,
#   '1229717': 41,
#   '1187892': 39,
#   '1188147': 38,
#   '1234011': 38,
#   '1234015': 38,
#   '1228467': 36,
#   '1231993': 36,
#   '1228494': 34,
#   '1228506': 34,
#   '1228605': 34,
#   '1228596': 34,
#   '1188598': 33,
#   '1195816': 32,
#   '1233077': 32,
#   '1233082': 32,
#   '1233072': 32,
#   '1184170': 32,
#   '1184176': 32,
#   '1189186': 32,
#   '1195824': 32,
#   '1182502': 31,
#   '1184978': 30,
#   '1184886': 30,
#   '1221456': 30,
#   '1184976': 30,
#   '1185948': 30,
#   '1184974': 30,
#   '1184980': 30,
#   '1185950': 30,
#   '1234007': 30,
#   '1184972': 30,
#   '1184970': 30,
#   '1231062': 29,
#   '1224461': 26,
#   '1186057': 26,
#   '1230296': 24,
#   '1182201': 24,
#   '1184108': 24,
#   '1188143': 23,
#   '1189620': 21,
#   '1223934': 20,
#   '1185879': 20,
#   '1223928': 20,
#   '1223931': 20,
#   '1185883': 20,
#   '1231454': 19,
#   '1223937': 19,
#   '1224526': 18,
#   '1187073': 17,
#   '1230292': 17,
#   '1223361': 17,
#   '1185826': 16,
#   '1190373': 16,
#   '1185647': 16,
#   '1186959': 16,
#   '1188637': 16,
#   '1185893': 16,
#   '1185827': 16,
#   '1187264': 16,
#   '1231189': 15,
#   '1231815': 15,
#   '1187462': 14,
#   '1188594': 14,
#   '1184389': 13,
#   '1183151': 13,
#   '1188602': 13,
#   '1190383': 12,
#   '1223156': 12,
#   '1190391': 12,
#   '1223158': 12,
#   '1190379': 12,
#   '1185831': 12,
#   '1190371': 12,
#   '1190381': 12,
#   '1190389': 12,
#   '1185829': 12,
#   '1190375': 12,
#   '1185828': 12,
#   '1190393': 12,
#   '1185976': 12,
#   '1185825': 12,
#   '1185832': 12,
#   '1190387': 12,
#   '1190377': 12,
#   '1229440': 12,
#   '1185830': 12,
#   '1224517': 12,
#   '1224457': 12,
#   '1190385': 12,
#   '1189041': 10,
#   '1189023': 10,
#   '1189061': 10,
#   '1189015': 10,
#   '1189039': 10,
#   '1189079': 10,
#   '1189033': 10,
#   '1188998': 10,
#   '1189003': 10,
#   '1188996': 10,
#   '1189095': 10,
#   '1189104': 10,
#   '1189108': 10,
#   '1189090': 10,
#   '1189089': 10,
#   '1189066': 10,
#   '1189035': 10,
#   '1188999': 10,
#   '1189025': 10,
#   '1189097': 10,
#   '1189006': 10,
#   '1189078': 10,
#   '1189101': 10,
#   '1189029': 10,
#   '1189038': 10,
#   '1189019': 10,
#   '1189070': 10,
#   '1189105': 10,
#   '1189009': 10,
#   '1189064': 10,
#   '1223349': 10,
#   '1189100': 10,
#   '1189076': 10,
#   '1189083': 10,
#   '1189065': 10,
#   '1189014': 10,
#   '1189016': 10,
#   '1189043': 10,
#   '1189040': 10,
#   '1189058': 10,
#   '1189017': 10,
#   '1189047': 10,
#   '1189110': 10,
#   '1189030': 10,
#   '1189085': 10,
#   '1189022': 10,
#   '1189107': 10,
#   '1189071': 10,
#   '1189088': 10,
#   '1189102': 10,
#   '1189062': 10,
#   '1189026': 10,
#   '1189024': 10,
#   '1189045': 10,
#   '1189056': 10,
#   '1189036': 10,
#   '1189053': 10,
#   '1189086': 10,
#   '1189093': 10,
#   '1189032': 10,
#   '1189027': 10,
#   '1189000': 10,
#   '1189074': 10,
#   '1189084': 10,
#   '1189057': 10,
#   '1189054': 10,
#   '1189098': 10,
#   '1189049': 10,
#   '1188997': 10,
#   '1189018': 10,
#   '1189028': 10,
#   '1189087': 10,
#   '1189037': 10,
#   '1189052': 10,
#   '1189011': 10,
#   '1189075': 10,
#   '1189013': 10,
#   '1189099': 10,
#   '1189069': 10,
#   '1189096': 10,
#   '1189063': 10,
#   '1189109': 10,
#   '1189092': 10,
#   '1189103': 10,
#   '1189050': 10,
#   '1189106': 10,
#   '1189048': 10,
#   '1189055': 10,
#   '1189111': 10,
#   '1189008': 10,
#   '1189005': 10,
#   '1189046': 10,
#   '1189034': 10,
#   '1189031': 10,
#   '1189059': 10,
#   '1189073': 10,
#   '1189004': 10,
#   '1189067': 10,
#   '1189060': 10,
#   '1189020': 10,
#   '1189082': 10,
#   '1187926': 10,
#   '1189001': 10,
#   '1189091': 10,
#   '1189081': 10,
#   '1189080': 10,
#   '1189002': 10,
#   '1189012': 10,
#   '1189010': 10,
#   '1189077': 10,
#   '1189042': 10,
#   '1189021': 10,
#   '1189068': 10,
#   '1189094': 10,
#   '1189007': 10,
#   '1189051': 10,
#   '1189072': 10,
#   '1189044': 10,
#   '1189623': 9,
#   '1223353': 9,
#   '1187928': 9,
#   '1223357': 9,
#   '1189633': 9,
#   '1223840': 8,
#   '1226038': 8,
#   '1226041': 8,
#   '1226044': 8,
#   '1185833': 8,
#   '1226047': 8,
#   '1224547': 8,
#   '1226050': 8,
#   '1226035': 8,
#   '1226053': 8,
#   '1227566': 8,
#   '1188150': 8,
#   '1224465': 7,
#   '1183147': 7,
#   '1188046': 7,
#   '1188044': 7,
#   '1185887': 7,
#   '1226437': 6,
#   '1186008': 6,
#   '1189626': 6,
#   '1185859': 6,
#   '1226433': 6,
#   '1183961': 6,
#   '1186010': 6,
#   '1226429': 6,
#   '1183540': 5,
#   '1229693': 5,
#   '1229695': 5,
#   '1221596': 5,
#   '1185095': 5,
#   '1229689': 5,
#   '1221597': 5,
#   '1183965': 5,
#   '1188667': 5,
#   '1196894': 4,
#   '1185146': 4,
#   '1228019': 4,
#   '1228024': 4,
#   '1223101': 4,
#   '1220534': 4,
#   '1196891': 4,
#   '1220536': 4,
#   '1228017': 4,
#   '1228016': 4,
#   '1184031': 4,
#   '1221605': 4,
#   '1228023': 4,
#   '1224464': 4,
#   '1229697': 4,
#   '1186957': 4,
#   '1228018': 4,
#   '1185835': 4,
#   '1228021': 4,
#   '1228020': 4,
#   '1196899': 4,
#   '1225109': 4,
#   '1185145': 4,
#   '1196912': 4,
#   '1224543': 4,
#   '1227043': 4,
#   '1196898': 4,
#   '1224545': 4,
#   '1226431': 4,
#   '1196895': 4,
#   '1184402': 4,
#   '1228022': 4,
#   '1220535': 4,
#   '1196910': 4,
#   '1226427': 4,
#   '1234817': 4,
#   '1226435': 4,
#   '1228015': 4,
#   '1188792': 4,
#   '1196911': 4,
#   '1196896': 4,
#   '1229687': 3,
#   '1188609': 3,
#   '1186961': 3,
#   '1187432': 3,
#   '1185979': 3,
#   '1221595': 3,
#   '1186958': 3,
#   '1189391': 3,
#   '1189390': 3,
#   '1236655': 3,
#   '1187242': 3,
#   '1187429': 3,
#   '1229691': 3,
#   '1188612': 3,
#   '1187678': 3,
#   '1221594': 3,
#   '1232600': 3,
#   '1196907': 2,
#   '1182116': 2,
#   '1196890': 2,
#   '1189464': 2,
#   '1182035': 2,
#   '1182023': 2,
#   '1189354': 2,
#   '1189477': 2,
#   '1196922': 2,
#   '1189474': 2,
#   '1196882': 2,
#   '1189348': 2,
#   '1196921': 2,
#   '1183069': 2,
#   '1182028': 2,
#   '1189471': 2,
#   '1182036': 2,
#   '1189358': 2,
#   '1182024': 2,
#   '1182031': 2,
#   '1189360': 2,
#   '1187227': 2,
#   '1189478': 2,
#   '1189468': 2,
#   '1182030': 2,
#   '1189466': 2,
#   '1182117': 2,
#   '1189480': 2,
#   '1196909': 2,
#   '1189377': 2,
#   '1196881': 2,
#   '1182039': 2,
#   '1189375': 2,
#   '1182027': 2,
#   '1182032': 2,
#   '1182034': 2,
#   '1182019': 2,
#   '1185834': 2,
#   '1189340': 2,
#   '1182038': 2,
#   '1182022': 2,
#   '1187443': 2,
#   '1196920': 2,
#   '1182017': 2,
#   '1189342': 2,
#   '1182029': 2,
#   '1189365': 2,
#   '1189465': 2,
#   '1196908': 2,
#   '1182026': 2,
#   '1182114': 2,
#   '1189350': 2,
#   '1189473': 2,
#   '1182020': 2,
#   '1189463': 2,
#   '1189346': 2,
#   '1189467': 2,
#   '1182025': 2,
#   '1187426': 2,
#   '1189472': 2,
#   '1189362': 2,
#   '1189470': 2,
#   '1189356': 2,
#   '1182115': 2,
#   '1182033': 2,
#   '1182037': 2,
#   '1189476': 2,
#   '1189344': 2,
#   '1189481': 2,
#   '1182021': 2,
#   '1186960': 2,
#   '1183071': 2,
#   '1182018': 2,
#   '1189475': 2,
#   '1189352': 2,
#   '1189482': 2,
#   '1189469': 2,
#   '1241351': 1,
#   '1238931': 1,
#   '1227088': 1,
#   '1183046': 1,
#   '1230926': 1,
#   '1230918': 1,
#   '1239589': 1,
#   '1242406': 1,
#   '1241761': 1,
#   '1186504': 1,
#   '1188110': 1,
#   '1242498': 1,
#   '1239540': 1,
#   '1240325': 1,
#   '1236012': 1,
#   '1241576': 1,
#   '1240995': 1,
#   '1239860': 1,
#   '1235989': 1,
#   '1238275': 1,
#   '1231604': 1,
#   '1240865': 1,
#   '1227089': 1,
#   '1236812': 1,
#   '1230909': 1,
#   '1242861': 1,
#   '1235962': 1,
#   '1238698': 1,
#   '1234324': 1,
#   '1187667': 1,
#   '1239047': 1,
#   '1230915': 1,
#   '1234335': 1,
#   '1242316': 1,
#   '1236014': 1,
#   '1189335': 1,
#   '1235665': 1,
#   '1242509': 1,
#   '1234336': 1,
#   '1183047': 1,
#   '1241565': 1,
#   '1239587': 1,
#   '1235884': 1,
#   '1188103': 1,
#   '1242307': 1,
#   '1236498': 1,
#   '1187676': 1,
#   '1236118': 1,
#   '1241599': 1,
#   '1235670': 1,
#   '1236124': 1,
#   '1235945': 1,
#   '1238940': 1,
#   '1241325': 1,
#   '1241347': 1,
#   '1239201': 1,
#   '1242337': 1,
#   '1189337': 1,
#   '1183646': 1,
#   '1241750': 1,
#   '1240112': 1,
#   '1231053': 1,
#   '1237831': 1,
#   '1239537': 1,
#   '1240234': 1,
#   '1183647': 1,
#   '1241539': 1,
#   '1241319': 1,
#   '1189338': 1,
#   '1187376': 1,
#   '1242318': 1,
#   '1243048': 1,
#   '1241306': 1,
#   '1242182': 1,
#   '1234239': 1,
#   '1236810': 1,
#   '1238830': 1,
#   '1238936': 1,
#   '1231600': 1,
#   '1238281': 1,
#   '1239580': 1,
#   '1238277': 1,
#   '1235876': 1,
#   '1237262': 1,
#   '1183648': 1,
#   '1238640': 1,
#   '1236117': 1,
#   '1241581': 1,
#   '1238971': 1,
#   '1239574': 1,
#   '1238966': 1,
#   '1236496': 1,
#   '1235916': 1,
#   '1241330': 1,
#   '1242324': 1,
#   '1241540': 1,
#   '1227483': 1,
#   '1238531': 1,
#   '1241308': 1,
#   '1182896': 1,
#   '1227265': 1,
#   '1241595': 1,
#   '1238270': 1,
#   '1242860': 1,
#   '1242898': 1,
#   '1238279': 1,
#   '1238550': 1,
#   '1227102': 1,
#   '1236095': 1,
#   '1187660': 1,
#   '1234272': 1,
#   '1236094': 1,
#   '1238827': 1,
#   '1188133': 1,
#   '1234149': 1,
#   '1238286': 1,
#   '1185871': 1,
#   '1242326': 1,
#   '1241547': 1,
#   '1238983': 1,
#   '1238933': 1,
#   '1188094': 1,
#   '1240880': 1,
#   '1188165': 1,
#   '1238951': 1,
#   '1236054': 1,
#   '1240659': 1,
#   '1240320': 1,
#   '1241353': 1,
#   '1242503': 1,
#   '1236200': 1,
#   '1235682': 1,
#   '1236027': 1,
#   '1241575': 1,
#   '1239862': 1,
#   '1187664': 1,
#   '1185308': 1,
#   '1236075': 1,
#   '1241561': 1,
#   '1240988': 1,
#   '1241340': 1,
#   '1242195': 1,
#   '1236047': 1,
#   '1238978': 1,
#   '1241311': 1,
#   '1236090': 1,
#   '1235951': 1,
#   '1236811': 1,
#   '1242202': 1,
#   '1239571': 1,
#   '1238666': 1,
#   '1227117': 1,
#   '1236146': 1,
#   '1238954': 1,
#   '1240882': 1,
#   '1234333': 1,
#   '1240318': 1,
#   '1236005': 1,
#   '1240118': 1,
#   '1241992': 1,
#   '1242180': 1,
#   '1241553': 1,
#   '1234261': 1,
#   '1238833': 1,
#   '1240094': 1,
#   '1233027': 1,
#   '1238620': 1,
#   '1240896': 1,
#   '1238847': 1,
#   '1240872': 1,
#   '1187673': 1,
#   '1227486': 1,
#   '1227096': 1,
#   '1235994': 1,
#   '1243153': 1,
#   '1240884': 1,
#   '1187674': 1,
#   '1241360': 1,
#   '1241327': 1,
#   '1187671': 1,
#   '1239562': 1,
#   '1241329': 1,
#   '1242305': 1,
#   '1236103': 1,
#   '1241337': 1,
#   '1240317': 1,
#   '1187659': 1,
#   '1240321': 1,
#   '1241312': 1,
#   '1234265': 1,
#   '1227103': 1,
#   '1242200': 1,
#   '1242338': 1,
#   '1219584': 1,
#   '1233359': 1,
#   '1240890': 1,
#   '1235888': 1,
#   '1241254': 1,
#   '1238822': 1,
#   '1241328': 1,
#   '1235920': 1,
#   '1238928': 1,
#   '1242189': 1,
#   '1186507': 1,
#   '1241571': 1,
#   '1227059': 1,
#   '1241307': 1,
#   '1234273': 1,
#   '1227082': 1,
#   '1239935': 1,
#   '1238532': 1,
#   '1230920': 1,
#   '1240589': 1,
#   '1238838': 1,
#   '1239289': 1,
#   '1238989': 1,
#   '1241570': 1,
#   '1240101': 1,
#   '1238962': 1,
#   '1240989': 1,
#   '1227076': 1,
#   '1241602': 1,
#   '1236195': 1,
#   '1239563': 1,
#   '1241432': 1,
#   '1235890': 1,
#   '1241309': 1,
#   '1237542': 1,
#   '1237830': 1,
#   '1242328': 1,
#   '1185306': 1,
#   '1242310': 1,
#   '1188127': 1,
#   '1234329': 1,
#   '1234270': 1,
#   '1236131': 1,
#   '1230917': 1,
#   '1239554': 1,
#   '1236104': 1,
#   '1234325': 1,
#   '1230910': 1,
#   '1241551': 1,
#   '1241342': 1,
#   '1187382': 1,
#   '1236168': 1,
#   '1236161': 1,
#   '1238649': 1,
#   '1241324': 1,
#   '1239594': 1,
#   '1227097': 1,
#   '1241315': 1,
#   '1236497': 1,
#   '1238282': 1,
#   '1238560': 1,
#   '1232729': 1,
#   '1234236': 1,
#   '1242327': 1,
#   '1241578': 1,
#   '1240888': 1,
#   '1235917': 1,
#   '1230922': 1,
#   '1187771': 1,
#   '1241313': 1,
#   '1189339': 1,
#   '1235991': 1,
#   '1238952': 1,
#   '1241555': 1,
#   '1242329': 1,
#   '1227080': 1,
#   '1241562': 1,
#   '1236013': 1,
#   '1239620': 1,
#   '1242183': 1,
#   '1183045': 1,
#   '1238976': 1,
#   '1236129': 1,
#   '1184029': 1,
#   '1242194': 1,
#   '1241754': 1,
#   '1240993': 1,
#   '1236194': 1,
#   '1241301': 1,
#   '1235874': 1,
#   '1238930': 1,
#   '1234334': 1,
#   '1186489': 1,
#   '1242306': 1,
#   '1236119': 1,
#   '1236053': 1,
#   '1240893': 1,
#   '1226316': 1,
#   '1227130': 1,
#   '1242325': 1,
#   '1241336': 1,
#   '1187675': 1,
#   '1238280': 1,
#   '1235910': 1,
#   '1230923': 1,
#   '1234345': 1,
#   '1188108': 1,
#   '1183184': 1,
#   '1238973': 1,
#   '1235980': 1,
#   '1236068': 1,
#   '1241352': 1,
#   '1238991': 1,
#   '1241566': 1,
#   '1240114': 1,
#   '1240110': 1,
#   '1238957': 1,
#   '1188126': 1,
#   '1240949': 1,
#   '1234341': 1,
#   '1241748': 1,
#   '1234268': 1,
#   '1236507': 1,
#   '1238284': 1,
#   '1237264': 1,
#   '1185652': 1,
#   '1240117': 1,
#   '1227078': 1,
#   '1239942': 1,
#   '1242507': 1,
#   '1242500': 1,
#   '1238841': 1,
#   '1235873': 1,
#   '1235921': 1,
#   '1241305': 1,
#   '1240898': 1,
#   '1242199': 1,
#   '1241584': 1,
#   '1242320': 1,
#   '1240886': 1,
#   '1242196': 1,
#   '1235992': 1,
#   '1237718': 1,
#   '1235932': 1,
#   '1242859': 1,
#   '1235930': 1,
#   '1227095': 1,
#   '1227567': 1,
#   '1235975': 1,
#   '1242505': 1,
#   '1239547': 1,
#   '1238958': 1,
#   '1235661': 1,
#   '1187672': 1,
#   '1238974': 1,
#   '1241429': 1,
#   '1241348': 1,
#   '1235928': 1,
#   '1235922': 1,
#   '1243312': 1,
#   '1240887': 1,
#   '1188163': 1,
#   '1241338': 1,
#   '1234339': 1,
#   '1227101': 1,
#   '1240327': 1,
#   '1238929': 1,
#   '1240326': 1,
#   '1239595': 1,
#   '1238988': 1,
#   '1188131': 1,
#   '1241339': 1,
#   '1227870': 1,
#   '1236113': 1,
#   '1236662': 1,
#   '1240990': 1,
#   '1234332': 1,
#   '1234331': 1,
#   '1238121': 1,
#   '1238977': 1,
#   '1230912': 1,
#   '1241320': 1,
#   '1242401': 1,
#   '1240871': 1,
#   '1227055': 1,
#   '1187379': 1,
#   '1236185': 1,
#   '1241316': 1,
#   '1241563': 1,
#   '1236202': 1,
#   '1236806': 1,
#   '1236165': 1,
#   '1238969': 1,
#   '1227085': 1,
#   '1236107': 1,
#   '1188082': 1,
#   '1236043': 1,
#   '1236112': 1,
#   '1241590': 1,
#   '1236089': 1,
#   '1241582': 1,
#   '1234151': 1,
#   '1240994': 1,
#   '1242177': 1,
#   '1239591': 1,
#   '1241541': 1,
#   '1183649': 1,
#   '1238356': 1,
#   '1230911': 1,
#   '1241560': 1,
#   '1242308': 1,
#   '1236173': 1,
#   '1238278': 1,
#   '1240874': 1,
#   '1238937': 1,
#   '1235937': 1,
#   '1242197': 1,
#   '1241598': 1,
#   '1241762': 1,
#   '1206800': 1,
#   '1235878': 1,
#   '1236155': 1,
#   '1236170': 1,
#   '1235970': 1,
#   '1241439': 1,
#   '1241546': 1,
#   '1182895': 1,
#   '1235883': 1,
#   '1241554': 1,
#   '1242179': 1,
#   '1238658': 1,
#   '1241443': 1,
#   '1240978': 1,
#   '1230916': 1,
#   '1233323': 1,
#   '1239560': 1,
#   '1241591': 1,
#   '1227142': 1,
#   '1242181': 1,
#   '1240235': 1,
#   '1238435': 1,
#   '1242312': 1,
#   '1237724': 1,
#   '1235958': 1,
#   ...},
#  'effect': {'MOR': 134451},
#  'conc1_mean': {'NR': 133155,
#   '100': 139,
#   '25': 137,
#   '1': 121,
#   '500': 91,
#   '50': 53,
#   '0.0071': 52,
#   '0.1': 50,
#   '2.44': 44,
#   '0.028': 43,
#   '10': 36,
#   '2.8': 26,
#   '150': 22,
#   '1.6': 18,
#   '5': 17,
#   '4.3': 16,
#   '4': 15,
#   '0.014': 15,
#   '1500': 14,
#   '0.029': 12,
#   '0.082': 11,
#   '83.9': 11,
#   '0.43': 10,
#   '0': 10,
#   '0.25': 9,
#   '0.021': 9,
#   '200': 9,
#   '0.0088': 8,
#   '231.4': 8,
#   '2': 7,
#   '0.071': 7,
#   '400': 7,
#   '0.5': 6,
#   '0.3': 6,
#   '0.00071': 6,
#   '125': 6,
#   '0.05': 6,
#   '2857': 6,
#   '0.03': 6,
#   '0.0005': 5,
#   '0.00008': 5,
#   '90': 5,
#   '0.016': 5,
#   '0.045': 5,
#   '0.0008': 5,
#   '900': 4,
#   '46': 4,
#   '444': 4,
#   '53': 4,
#   '0.8': 4,
#   '0.27': 4,
#   '47': 4,
#   '0.07': 4,
#   '122.5': 4,
#   '0.06': 4,
#   '1.4': 4,
#   '8': 3,
#   '20': 3,
#   '0.75': 3,
#   '71.4': 3,
#   '365': 3,
#   '554': 3,
#   '250': 3,
#   '300': 3,
#   '65': 3,
#   '800': 3,
#   '196.4': 3,
#   '0.1478': 2,
#   '104': 2,
#   '4029': 2,
#   '0.01': 2,
#   '736': 2,
#   '376': 2,
#   '30': 2,
#   '2.99': 2,
#   '600': 2,
#   '0.035': 2,
#   '0.0177': 2,
#   '35': 2,
#   '0.007': 2,
#   '16': 2,
#   '0.005': 2,
#   '15.6': 2,
#   '50.9': 2,
#   '1494': 2,
#   '0.0044': 2,
#   '1109': 2,
#   '0.02': 2,
#   '44': 2,
#   '0.9': 2,
#   '223': 2,
#   '296': 2,
#   '577': 2,
#   '27': 1,
#   '15': 1,
#   '2500': 1,
#   '29': 1,
#   '8.48': 1,
#   '550': 1,
#   '0.74': 1,
#   '1.75': 1,
#   '222': 1,
#   '3': 1,
#   '4000': 1,
#   '4900': 1,
#   '1.5': 1,
#   '4750': 1,
#   '560': 1,
#   '2.97': 1,
#   '0.72': 1,
#   '19.95': 1,
#   '2050': 1,
#   '608': 1,
#   '2000': 1,
#   '9900': 1,
#   '1.42': 1,
#   '2.5': 1,
#   '12.8': 1,
#   '480': 1,
#   '30.41': 1,
#   '1331': 1,
#   '1200': 1,
#   '25.5': 1,
#   '55': 1,
#   '17.27': 1,
#   '3000': 1,
#   '60.83': 1,
#   '4175': 1,
#   '4500': 1,
#   '244': 1,
#   '1525': 1,
#   '0.075': 1,
#   '14.6': 1,
#   '350': 1,
#   '2.25': 1,
#   '239': 1,
#   '0.2': 1,
#   '0.28': 1,
#   '2948': 1,
#   '28': 1,
#   '52.49': 1,
#   '14': 1,
#   '11.25': 1,
#   '0.03696': 1,
#   '2350': 1,
#   '3428': 1,
#   '114.9': 1,
#   '24': 1,
#   '75': 1,
#   '450': 1,
#   '5000': 1,
#   '205.72': 1,
#   '545': 1,
#   '101.8': 1,
#   '39.8': 1,
#   '80': 1,
#   '51.25': 1,
#   '2700': 1,
#   '34': 1,
#   '6.6': 1,
#   '390': 1},
#  'conc2_mean': {0: 132395,
#   'NR': 724,
#   '10': 530,
#   '3.3': 480,
#   '0.001': 310,
#   '25': 12},
#  'conc3_mean': {0: 134451},
#  'dose_id': {'75178': 3234,
#   '75193': 2916,
#   '75189': 2880,
#   '79445': 2288,
#   '79446': 2256,
#   '79447': 2256,
#   '79448': 2256,
#   '79449': 2256,
#   '75186': 2058,
#   '75164': 1920,
#   '75184': 1806,
#   '75182': 1722,
#   '75199': 1692,
#   '75176': 1680,
#   '75180': 1680,
#   '75197': 1512,
#   '75195': 1476,
#   '75191': 1440,
#   '70989': 1232,
#   '75174': 1200,
#   '70988': 1188,
#   '70987': 1166,
#   '70986': 1144,
#   '70985': 1007,
#   '75166': 960,
#   '75172': 960,
#   '75168': 960,
#   '75170': 960,
#   '70992': 936,
#   '70994': 936,
#   '70991': 936,
#   '75190': 864,
#   '75209': 820,
#   '75183': 798,
#   '75179': 756,
#   '75181': 756,
#   '75177': 714,
#   '75158': 672,
#   '75162': 672,
#   '75192': 648,
#   '75198': 648,
#   '70984': 646,
#   '75154': 640,
#   '75160': 640,
#   '75156': 640,
#   '70709': 630,
#   '75185': 630,
#   '70710': 630,
#   '70708': 630,
#   '75196': 612,
#   '70993': 612,
#   '75194': 612,
#   '74068': 600,
#   '74070': 600,
#   '74072': 600,
#   '74069': 600,
#   '74067': 600,
#   '74071': 600,
#   '74061': 540,
#   '74064': 540,
#   '74062': 540,
#   '74063': 540,
#   '74065': 540,
#   '75218': 500,
#   '3719': 490,
#   '3715': 490,
#   '3717': 490,
#   '3718': 490,
#   '3716': 490,
#   '76273': 448,
#   '76272': 448,
#   '75165': 432,
#   '75171': 432,
#   '75167': 432,
#   '75169': 432,
#   '75173': 432,
#   '75280': 416,
#   '75211': 400,
#   '75203': 400,
#   '75207': 400,
#   '75205': 400,
#   '76271': 400,
#   '79695': 384,
#   '79694': 384,
#   '79698': 384,
#   '79696': 384,
#   '79699': 384,
#   '79697': 384,
#   '75272': 352,
#   '70407': 348,
#   '71051': 336,
#   '71050': 336,
#   '74739': 308,
#   '74066': 306,
#   '70406': 300,
#   '71053': 294,
#   '71052': 294,
#   '73056': 292,
#   '73057': 292,
#   '73060': 292,
#   '73058': 292,
#   '73059': 292,
#   '75155': 288,
#   '75161': 288,
#   '75157': 288,
#   '79703': 286,
#   '79702': 286,
#   '79700': 286,
#   '70990': 286,
#   '79701': 286,
#   '73055': 284,
#   '74600': 276,
#   '74599': 276,
#   '74598': 276,
#   '74595': 272,
#   '74763': 270,
#   '74746': 270,
#   '74762': 270,
#   '75163': 256,
#   '75153': 256,
#   '75159': 256,
#   '75188': 252,
#   '75147': 252,
#   '75141': 252,
#   '75145': 252,
#   '74757': 240,
#   '76965': 232,
#   '76964': 232,
#   '75143': 224,
#   '74738': 224,
#   '75149': 224,
#   '75201': 216,
#   '75283': 208,
#   '75276': 208,
#   '75278': 208,
#   '75279': 208,
#   '75281': 208,
#   '75277': 208,
#   '75282': 208,
#   '74750': 190,
#   '74748': 190,
#   '74759': 190,
#   '74756': 190,
#   '75208': 180,
#   '75219': 180,
#   '75204': 180,
#   '75212': 180,
#   '75269': 176,
#   '75270': 176,
#   '75274': 176,
#   '75271': 176,
#   '75268': 176,
#   '75275': 176,
#   '75273': 176,
#   '75210': 170,
#   '75206': 170,
#   '75202': 160,
#   '79744': 152,
#   '79745': 152,
#   '79746': 152,
#   '79750': 152,
#   '75133': 150,
#   '55022': 144,
#   '55033': 144,
#   '55018': 144,
#   '55017': 144,
#   '55026': 144,
#   '55032': 144,
#   '79747': 144,
#   '79743': 144,
#   '55048': 144,
#   '55034': 144,
#   '55025': 144,
#   '55040': 144,
#   '79748': 144,
#   '55014': 144,
#   '55038': 144,
#   '55047': 144,
#   '55010': 144,
#   '55041': 144,
#   '55024': 144,
#   '55030': 144,
#   '55039': 144,
#   '55049': 144,
#   '55042': 144,
#   '79749': 144,
#   '55016': 144,
#   '55046': 144,
#   '55031': 144,
#   '55015': 144,
#   '55023': 144,
#   '3401': 140,
#   '3402': 140,
#   '3403': 140,
#   '3399': 140,
#   '72414': 140,
#   '68994': 132,
#   '68993': 132,
#   '68996': 132,
#   '68992': 132,
#   '74848': 126,
#   '71619': 124,
#   '72496': 124,
# ...
#   '680737': 1,
#   '679226': 1,
#   '648566': 1,
#   '653228': 1,
#   '665411': 1,
#   '647204': 1,
#   '653610': 1,
#   '647919': 1,
#   '680890': 1,
#   '639946': 1,
#   '670671': 1,
#   '682630': 1,
#   '672117': 1,
#   '682631': 1,
#   '653263': 1,
#   '682889': 1,
#   '672221': 1,
#   '654188': 1,
#   '657206': 1,
#   '669100': 1,
#   '683386': 1,
#   '682647': 1,
#   '657462': 1,
#   '665409': 1,
#   '672114': 1,
#   '653298': 1,
#   '648961': 1,
#   '659333': 1,
#   '640577': 1,
#   '653337': 1,
#   '639932': 1,
#   '665047': 1,
#   '653203': 1,
#   '684441': 1,
#   '680184': 1,
#   '680210': 1,
#   '682896': 1,
#   '651320': 1,
#   '680172': 1,
#   '663271': 1,
#   '680195': 1,
#   '680200': 1,
#   '680228': 1,
#   '681649': 1,
#   '680209': 1,
#   '671151': 1,
#   '649283': 1,
#   '665941': 1,
#   '680197': 1,
#   '653238': 1,
#   '683420': 1,
#   '653199': 1,
#   '646941': 1,
#   '653190': 1,
#   '646724': 1,
#   '680771': 1,
#   '653297': 1,
#   '646568': 1,
#   '649280': 1,
#   '650848': 1,
#   '680224': 1,
#   '639950': 1,
#   '669128': 1,
#   '649226': 1,
#   '681641': 1,
#   '653352': 1,
#   '659980': 1,
#   '639953': 1,
#   '683916': 1,
#   '680187': 1,
#   '653235': 1,
#   '653291': 1,
#   '640695': 1,
#   '680821': 1,
#   '653265': 1,
#   '665422': 1,
#   '669148': 1,
#   '682750': 1,
#   '653259': 1,
#   '649281': 1,
#   '682809': 1,
#   '654755': 1,
#   '653218': 1,
#   '653366': 1,
#   '653233': 1,
#   '651319': 1,
#   '653309': 1,
#   '638668': 1,
#   '680881': 1,
#   '639939': 1,
#   '653349': 1,
#   '652621': 1,
#   '681140': 1,
#   '680802': 1,
#   '640167': 1,
#   '669108': 1,
#   '680212': 1,
#   '646934': 1,
#   '663731': 1,
#   '649238': 1,
#   '665396': 1,
#   '647086': 1,
#   '682856': 1,
#   '649286': 1,
#   '653355': 1,
#   '680181': 1,
#   '653280': 1,
#   '665055': 1,
#   '672214': 1,
#   '673893': 1,
#   '686199': 1,
#   '665403': 1,
#   '681106': 1,
#   '653221': 1,
#   '649227': 1,
#   '680801': 1,
#   '653296': 1,
#   '680183': 1,
#   '683409': 1,
#   '680815': 1,
#   '653370': 1,
#   '678393': 1,
#   '647907': 1,
#   '643849': 1,
#   '649279': 1,
#   '638276': 1,
#   '653209': 1,
#   '682900': 1,
#   '680218': 1,
#   '682624': 1,
#   '684033': 1,
#   '665392': 1,
#   '672216': 1,
#   '682852': 1,
#   '669082': 1,
#   '638644': 1,
#   '649246': 1,
#   '650874': 1,
#   '674284': 1,
#   '683412': 1,
#   '640639': 1,
#   '650918': 1,
#   '680731': 1,
#   '669136': 1,
#   '682858': 1,
#   '672109': 1,
#   '678415': 1,
#   '653628': 1,
#   '639940': 1,
#   '646996': 1,
#   '682861': 1,
#   '653329': 1,
#   '650872': 1,
#   '680885': 1,
#   '656160': 1,
#   '650911': 1,
#   '663726': 1,
#   '674287': 1,
#   '647114': 1,
#   '670673': 1,
#   '683926': 1,
#   '684079': 1,
#   '653243': 1,
#   '650912': 1,
#   '645027': 1,
#   '669118': 1,
#   '653341': 1,
#   '669081': 1,
#   '654753': 1,
#   '649267': 1,
#   '653369': 1,
#   '680177': 1,
#   '665423': 1,
#   '661430': 1,
#   '652745': 1,
#   '680176': 1,
#   '674278': 1,
#   '680221': 1,
#   '682888': 1,
#   '653247': 1,
#   '647093': 1,
#   '640641': 1,
#   '678398': 1,
#   '680792': 1,
#   '669147': 1,
#   '682633': 1,
#   '674285': 1,
#   '649808': 1,
#   '665354': 1,
#   '680352': 1,
#   '659370': 1,
#   '680174': 1,
#   '677012': 1,
#   '639951': 1,
#   '678408': 1,
#   '653333': 1,
#   '653249': 1,
#   ...},
#  'cas_number': {'64175': 59849,
#   '8001307': 28320,
#   '67641': 11385,
#   '7732185': 10975,
#   '51796': 5672,
#   '63423': 3972,
#   '118741': 2450,
#   '7647145': 2421,
#   '67561': 1788,
#   '57556': 1684,
#   '8002037': 791,
#   '75058': 712,
#   '9005703': 631,
#   '25322694': 630,
#   '109660': 580,
#   '8001250': 502,
#   '57501': 453,
#   '8001294': 346,
#   '67685': 288,
#   '7697372': 184,
#   '308069138': 154,
#   '9004675': 72,
#   '68956683': 71,
#   '9000015': 70,
#   '64197': 67,
#   '110543': 64,
#   '8012951': 46,
#   '63148696': 43,
#   '110805': 40,
#   '6092542': 32,
#   '67663': 26,
#   '9005656': 18,
#   '1310732': 16,
#   '1330207': 14,
#   '12687900': 12,
#   '7647010': 11,
#   '37189198': 9,
#   '8008206': 8,
#   '9005645': 8,
#   '124389': 6,
#   '12774300': 4,
#   '7447407': 4,
#   '75092': 3,
#   '8008740': 2,
#   '8002139': 2,
#   '9004324': 2,
#   '9016459': 2,
#   '1327362': 1,
#   '71432': 1,
#   '56815': 1,
#   '308060744': 1,
#   '8001227': 1,
#   '9000651': 1,
#   '9010440': 1,
#   '57885': 1,
#   '100663': 1,
#   '10504355': 1,
#   '100516': 1,
#   '1305620': 1},
#  'chem_name': {'Ethanol': 59849,
#   'Corn oil': 28320,
#   '2-Propanone': 11385,
#   'Water': 10975,
#   'Carbamic acid, Ethyl ester': 5672,
#   '4-O-beta-D-Galactopyranosyl-D-glucose': 3972,
#   '1,2,3,4,5,6-Hexachlorobenzene': 2450,
#   'Sodium chloride (NaCl)': 2421,
#   'Methanol': 1788,
#   '1,2-Propanediol': 1684,
#   'Peanut oil': 791,
#   'Acetonitrile': 712,
#   'Sorbitan, Tri-9-octadecenoate, Poly(oxy-1,2-ethanediyl)derivs., (Z,Z,Z)-': 631,
#   'Polypropylene glycol': 630,
#   'Pentane': 580,
#   'Olive oil': 502,
#   'alpha-D-Glucopyranoside, beta-D-Fructofuranosyl': 453,
#   'Cottonseed oil': 346,
#   'Sulfinyl bis(methane)': 288,
#   'Nitric acid': 184,
#   'Perfluorocarbons': 154,
#   'Cellulose, Methyl ether': 72,
#   'Fats and Glyceridic oils, Vegetable': 71,
#   'Gum arabic': 70,
#   'Acetic acid': 67,
#   'Hexane': 64,
#   'Paraffin oils': 46,
#   'Alkyd resins': 43,
#   '2-Ethoxyethanol': 40,
#   'Chloroformic acid, Hexyl ester': 32,
#   'Trichloromethane': 26,
#   'Sorbitan, Mono-9-octadecenoate, (Z)-Poly(oxy-1,2-ethanediyl) derivs.': 18,
#   'Sodium hydroxide': 16,
#   'Dimethylbenzene': 14,
#   'Ortho X 77': 12,
#   'Hydrochloric acid': 11,
#   'Spreader sticker': 9,
#   'Sorbitan, Monododecanoate, Poly(oxy-1,2-ethanediyl)derivs.': 8,
#   'Kerosine (petroleum)': 8,
#   'Carbon dioxide': 6,
#   'Corexit 7664': 4,
#   'Potassium chloride (KCl)': 4,
#   'Methylene chloride': 3,
#   'Fats and glyceridic oils, Sesame': 2,
#   'Rape oil': 2,
#   'alpha-(Nonylphenyl)-omega-hydroxypoly(oxy-1,2-ethanediyl)': 2,
#   'Cellulose, Carboxymethyl ether, Sodium salt': 2,
#   'Benzene': 1,
#   'Albumins': 1,
#   'Triton X 155': 1,
#   'Soybean oil': 1,
#   'Calcium hydroxide (Ca(OH)2)': 1,
#   '3 beta-Cholest-5-en-3-ol': 1,
#   'Gum tragacanth': 1,
#   'Methoxybenzene': 1,
#   '1,2,3-Propanetriol': 1,
#   'Ascorbic acid': 1,
#   'Aluminatesilicate': 1,
#   'Benzenemethanol': 1},
#  'formulation': {'NR': 133242,
#   'NC': 912,
#   'CO': 200,
#   'C': 64,
#   'AI': 16,
#   'ES': 14,
#   'PU': 3},
#  'chemical_name': {'Ethanol': 59849,
#   'Corn oil': 28320,
#   '2-Propanone': 11385,
#   'Water': 10975,
#   'Carbamic acid, Ethyl ester': 5672,
#   '4-O-beta-D-Galactopyranosyl-D-glucose': 3972,
#   '1,2,3,4,5,6-Hexachlorobenzene': 2450,
#   'Sodium chloride (NaCl)': 2421,
#   'Methanol': 1788,
#   '1,2-Propanediol': 1684,
#   'Peanut oil': 791,
#   'Acetonitrile': 712,
#   'Sorbitan, Tri-9-octadecenoate, Poly(oxy-1,2-ethanediyl)derivs., (Z,Z,Z)-': 631,
#   'Polypropylene glycol': 630,
#   'Pentane': 580,
#   'Olive oil': 502,
#   'alpha-D-Glucopyranoside, beta-D-Fructofuranosyl': 453,
#   'Cottonseed oil': 346,
#   'Sulfinyl bis(methane)': 288,
#   'Nitric acid': 184,
#   'Perfluorocarbons': 154,
#   'Cellulose, Methyl ether': 72,
#   'Fats and Glyceridic oils, Vegetable': 71,
#   'Gum arabic': 70,
#   'Acetic acid': 67,
#   'Hexane': 64,
#   'Paraffin oils': 46,
#   'Alkyd resins': 43,
#   '2-Ethoxyethanol': 40,
#   'Chloroformic acid, Hexyl ester': 32,
#   'Trichloromethane': 26,
#   'Sorbitan, Mono-9-octadecenoate, (Z)-Poly(oxy-1,2-ethanediyl) derivs.': 18,
#   'Sodium hydroxide': 16,
#   'Dimethylbenzene': 14,
#   'Ortho X 77': 12,
#   'Hydrochloric acid': 11,
#   'Spreader sticker': 9,
#   'Sorbitan, Monododecanoate, Poly(oxy-1,2-ethanediyl)derivs.': 8,
#   'Kerosine (petroleum)': 8,
#   'Carbon dioxide': 6,
#   'Corexit 7664': 4,
#   'Potassium chloride (KCl)': 4,
#   'Methylene chloride': 3,
#   'Fats and glyceridic oils, Sesame': 2,
#   'Rape oil': 2,
#   'alpha-(Nonylphenyl)-omega-hydroxypoly(oxy-1,2-ethanediyl)': 2,
#   'Cellulose, Carboxymethyl ether, Sodium salt': 2,
#   'Benzene': 1,
#   'Albumins': 1,
#   'Triton X 155': 1,
#   'Soybean oil': 1,
#   'Calcium hydroxide (Ca(OH)2)': 1,
#   '3 beta-Cholest-5-en-3-ol': 1,
#   'Gum tragacanth': 1,
#   'Methoxybenzene': 1,
#   '1,2,3-Propanetriol': 1,
#   'Ascorbic acid': 1,
#   'Aluminatesilicate': 1,
#   'Benzenemethanol': 1},
#  'common_name': {'Norway Rat': 78737,
#   'House Mouse': 16684,
#   'Mallard Duck': 5882,
#   'Earthworm': 5768,
#   'Japanese Quail': 4658,
#   'Ring-Necked Pheasant': 4180,
#   'American Black Duck': 3186,
#   'Yellow Nutsedge': 1813,
#   'Springtail': 1407,
#   'Common Barn-Owl': 1260,
#   'Chinese Ring-Necked Pheasant': 1184,
#   'Coyote': 919,
#   'Pig': 883,
#   'American Kestrel': 849,
#   'Domestic Chicken': 802,
#   'Domestic Sheep': 701,
#   'Northern Bobwhite Quail': 673,
#   'Japanese Beetle': 632,
#   'Sour Paste Nematode': 416,
#   'Hispid Cotton Rat': 370,
#   'American Mink': 348,
#   'Honey Bee': 318,
#   'Southern House Mosquito': 296,
#   'Double-Crested Cormorant': 215,
#   'Quail': 180,
#   'Golden Hamster': 145,
#   'Guinea Pig': 130,
#   'Common Rough Woodlouse': 106,
#   'Brown-Headed Cowbird': 104,
#   'European Rabbit': 101,
#   'Loggerhead Shrike': 98,
#   'Mosquito': 88,
#   'Soybean': 83,
#   'Pigeon': 80,
#   'Confused Flour Beetle': 60,
#   'Cigarette Beetle': 59,
#   'Bald Eagle': 57,
#   'Purple Crabgrass': 54,
#   'European Starling': 48,
#   'Dermestid Beetle': 41,
#   'Carrot Rust Fly': 40,
#   'Tomato Hornworm': 39,
#   'Coffee Leafminer': 39,
#   'Common Field Cricket': 38,
#   'Tobacco Budworm': 36,
#   'Fruit Fly': 36,
#   'Yellow Fever Mosquito': 31,
#   'Rock Dove': 31,
#   'Cricket': 30,
#   'American Robin': 28,
#   'Fall Armyworm': 26,
#   'Perennial Ryegrass': 24,
#   'Parasitic Wasp': 23,
#   'Budworm': 20,
#   'Zebra Finch': 16,
#   'European Nightcrawler': 16,
#   'White-Tailed Deer': 16,
#   'Cutworm': 15,
#   'American Cockroach': 15,
#   'House Fly': 13,
#   'Mite': 13,
#   'Leopard Frog': 13,
#   'Variegated Cutworm': 12,
#   'Protozoan Phylum': 12,
#   'Egyptian Cotton Leafworm': 11,
#   'Corn Earworm': 11,
#   'Mongolian Jird': 11,
#   'Enchytraeid Worm': 11,
#   'Ladybird Beetle': 11,
#   'Convergent Lady Beetle': 9,
#   'Two-Spotted Spider Mite': 9,
#   'Cryptostigmatid Mite': 8,
#   'Old World Bollworm': 8,
#   'Carrot Weevil': 8,
#   'Common Grackle': 8,
#   'Nematode': 7,
#   'African Clawed Frog': 7,
#   'Mason Bee': 7,
#   'Soft Tick': 6,
#   'American Alligator': 6,
#   'Oligochaete Family': 6,
#   'Bullfrog': 5,
#   'Rust-Red Flour Beetle': 5,
#   'Grey Field Slug': 5,
#   'Spotted Salamander': 4,
#   'Braconid Wasp': 4,
#   'Spotless Ladybird Beetle': 4,
#   'Darksided Cutworm': 4,
#   'Indian Earthworm': 4,
#   'Giant Garden Slug': 4,
#   'Brown Gardensnail': 4,
#   'American House Dust Mite': 4,
#   'Mule Deer': 4,
#   'Kangaroo Rat': 3,
#   'Domestic Dog': 3,
#   'Escorpi O': 3,
#   'Red-Eared Slider': 3,
#   'Habu': 3,
#   'Formosan Subterranean Termite': 3,
#   'White Cutworm': 3,
#   'German Cockroach': 2,
#   'Oriental Cockroach': 2,
#   'Blue-Winged Teal': 2,
#   'Bee': 2,
#   'Smartweed': 2,
#   'Wimmera Ryegrass': 2,
#   'Giant African Snail': 2,
#   'House Sparrow': 2,
#   'Mamushi': 2,
#   'Red-Winged Blackbird': 2,
#   'Beet Armyworm': 2,
#   'Sowbug': 2,
#   'Bridal Robe': 2,
#   'California Rape': 1,
#   'Termite': 1,
#   'Wood Duck': 1,
#   'Gray Short-Tailed Opossum': 1,
#   'Papaya': 1,
#   'Frog And Toad Order': 1,
#   'Alfalfa Leafcutter Bee': 1,
#   'Isopod': 1,
#   'Oldfield Mouse': 1,
#   'Lyctid Beetle': 1,
#   'Northern Red Oak': 1,
#   'Map Turtles': 1},
#  'kingdom': {'Animalia': 132468, 'Plantae': 1983},
#  'class': {'Mammalia': 99057,
#   'Aves': 23546,
#   'Clitellata': 5790,
#   'Insecta': 2006,
#   'Liliopsida': 1893,
#   'Entognatha': 1407,
#   'Secernentea': 423,
#   'Malacostraca': 109,
#   'Magnoliopsida': 90,
#   'Arachnida': 43,
#   'Amphibia': 30,
#   'Reptilia': 15,
#   'Gastropoda': 15,
#   'Oligochaeta': 15,
#   0: 12},
#  'tax_order': {'Rodentia': 96081,
#   'Galliformes': 11677,
#   'Anseriformes': 9071,
#   'Lumbriculida': 5790,
#   'Cyperales': 1893,
#   'Artiodactyla': 1604,
#   'Collembola': 1407,
#   'Carnivora': 1270,
#   'Strigiformes': 1260,
#   'Falconiformes': 849,
#   'Coleoptera': 830,
#   'Diptera': 504,
#   'Rhabditida': 423,
#   'Hymenoptera': 355,
#   'Passeriformes': 306,
#   'Lepidoptera': 226,
#   'Suliformes': 215,
#   'Columbiformes': 111,
#   'Isopoda': 109,
#   'Lagomorpha': 101,
#   'Fabales': 83,
#   'Orthoptera': 68,
#   'Accipitriformes': 57,
#   'Anura': 26,
#   'Dictyoptera': 17,
#   'Haplotaxida': 15,
#   'Stylommatophora': 15,
#   'Trombidiformes': 13,
#   0: 12,
#   'Mesostigmata': 9,
#   'Sarcoptiformes': 8,
#   'Crocodilia': 6,
#   'Parasitiformes': 6,
#   'Squamata': 5,
#   'Astigmata': 4,
#   'Isoptera': 4,
#   'Caudata': 4,
#   'Testudines': 4,
#   'Scorpiones': 3,
#   'Blattodea': 2,
#   'Asterales': 2,
#   'Caryophyllales': 2,
#   'Didelphimorphia': 1,
#   'Brassicales': 1,
#   'Violales': 1,
#   'Fagales': 1},
#  'family': {'Muridae': 95948,
#   'Phasianidae': 11004,
#   'Anatidae': 9071,
#   'Lumbricidae': 5790,
#   'Cyperaceae': 1813,
#   'Isotomidae': 1398,
#   'Tytonidae': 1260,
#   'Canidae': 922,
#   'Suidae': 883,
#   'Falconidae': 849,
#   'Bovidae': 701,
#   'Odontophoridae': 673,
#   'Scarabaeidae': 632,
#   'Panagrolaimidae': 416,
#   'Culicidae': 415,
#   'Mustelidae': 348,
#   'Apidae': 320,
#   'Phalacrocoracidae': 215,
#   'Noctuidae': 148,
#   'Caviidae': 130,
#   'Fringillidae': 114,
#   'Columbidae': 111,
#   'Porcellionidae': 108,
#   'Leporidae': 101,
#   'Laniidae': 98,
#   'Fabaceae': 83,
#   'Poaceae': 80,
#   'Gryllidae': 68,
#   'Tenebrionidae': 65,
#   'Anobiidae': 59,
#   'Accipitridae': 57,
#   'Sturnidae': 48,
#   'Dermestidae': 41,
#   'Psilidae': 40,
#   'Lyonetiidae': 39,
#   'Sphingidae': 39,
#   'Drosophilidae': 36,
#   'Muscicapidae': 28,
#   'Coccinellidae': 24,
#   'Cervidae': 20,
#   'Ranidae': 18,
#   'Aphelinidae': 18,
#   'Blattidae': 17,
#   0: 16,
#   'Estrildidae': 16,
#   'Muscidae': 13,
#   'Enchytraeidae': 11,
#   'Tetranychidae': 9,
#   'Varroidae': 9,
#   'Limacidae': 9,
#   'Megachilidae': 8,
#   'Curculionidae': 8,
#   'Onychiuridae': 8,
#   'Trhypochthoniidae': 8,
#   'Rhabditidae': 7,
#   'Pipidae': 7,
#   'Argasidae': 6,
#   'Alligatoridae': 6,
#   'Viperidae': 5,
#   'Megascolecidae': 4,
#   'Rhinotermitidae': 4,
#   'Braconidae': 4,
#   'Tarsonemidae': 4,
#   'Ichneumonidae': 4,
#   'Pyroglyphidae': 4,
#   'Ambystomatidae': 4,
#   'Emydidae': 4,
#   'Helicidae': 4,
#   'Heteromyidae': 3,
#   'Asteraceae': 2,
#   'Passeridae': 2,
#   'Blattellidae': 2,
#   'Polygonaceae': 2,
#   'Achatinidae': 2,
#   'Fagaceae': 1,
#   'Bostrichidae': 1,
#   'Didelphidae': 1,
#   'Entomobryidae': 1,
#   'Armadillidiidae': 1,
#   'Trichogrammatidae': 1,
#   'Caricaceae': 1,
#   'Brassicaceae': 1},
#  'species': {'norvegicus': 78737,
#   'musculus': 15544,
#   'platyrhynchos': 5882,
#   'colchicus': 5364,
#   'japonica': 5290,
#   'terrestris': 3808,
#   'rubripes': 3186,
#   'esculentus': 1813,
#   'candida': 1398,
#   'alba': 1260,
#   'sp.': 1239,
#   'andrei': 952,
#   'latrans': 919,
#   'scrofa': 882,
#   'sparverius': 849,
#   'domesticus': 834,
#   'fetida': 792,
#   'aries': 701,
#   'virginianus': 689,
#   'redividus': 416,
#   'hispidus': 370,
#   'vison': 348,
#   'mellifera': 318,
#   'quinquefasciatus': 296,
#   'auritus': 215,
#   'coturnix': 180,
#   'auratus': 145,
#   'porcellus': 130,
#   'rubellus': 109,
#   'scaber': 106,
#   'ater': 104,
#   'cuniculus': 101,
#   'ludovicianus': 98,
#   'caliginosa': 84,
#   'max': 83,
#   'stephensi': 63,
#   'confusum': 60,
#   'unicolor': 59,
#   'leucocephalus': 57,
#   'virescens': 56,
#   'sanguinalis': 54,
#   'vulgaris': 48,
#   'glabrum': 41,
#   'rosae': 40,
#   'quinquemaculata': 39,
#   'coffeella': 39,
#   'pennsylvanicus': 38,
#   'melanogaster': 36,
#   'pipiens': 34,
#   'aegypti': 31,
#   'livia': 31,
#   'migratorius': 28,
#   'frugiperda': 26,
#   'perenne': 24,
#   0: 22,
#   'veneta': 18,
#   'perpallidus': 18,
#   'hortensis': 16,
#   'guttata': 16,
#   'americana': 15,
#   'ipsilon': 15,
#   'domestica': 14,
#   'saucia': 12,
#   'zea': 11,
#   'crypticus': 11,
#   'unguiculatus': 11,
#   'v-nigrum': 11,
#   'littoralis': 11,
#   'convergens': 9,
#   'jacobsoni': 9,
#   'urticae': 9,
#   'armigera': 8,
#   'quiscula': 8,
#   'oregonensis': 8,
#   'armata': 8,
#   'elegans': 7,
#   'laevis': 7,
#   'lignaria': 7,
#   'mississippiensis': 6,
#   'moubata': 6,
#   'catesbeiana': 5,
#   'castaneum': 5,
#   'reticulatum': 5,
#   'chlorotica': 5,
#   'woodi': 4,
#   'sanguinea': 4,
#   'trivittatus': 4,
#   'messoria': 4,
#   'posthuma': 4,
#   'farinae': 4,
#   'marginiventris': 4,
#   'aspersa': 4,
#   'hemionus': 4,
#   'maximus': 4,
#   'maculatum': 4,
#   'scripta': 3,
#   'flavoviridis': 3,
#   'familiaris': 3,
#   'scandens': 3,
#   'formosanus': 3,
#   'rigidum': 2,
#   'inodorum': 2,
#   'lapathifolium': 2,
#   'exigua': 2,
#   'blomhoffii': 2,
#   'dilatatus': 2,
#   'germanica': 2,
#   'orientalis': 2,
#   'fulica': 2,
#   'phoeniceus': 2,
#   'discors': 2,
#   'rotundata': 1,
#   'papaya': 1,
#   'sponsa': 1,
#   'brunneus': 1,
#   'vulgare': 1,
#   'cincta': 1,
#   'gestroi': 1,
#   'arvensis': 1,
#   'rubra': 1,
#   'brassicae': 1,
#   'polionotus': 1}}

# %%
df_clone = df # Just a df restart for test

# %% [markdown]
# The relation table will have the value for each species in effect Measument  values

# %%
df_columns  = list(measurement_dict.keys())
df_columns  = ["Species"] + df_columns

df_new      = pd.DataFrame(columns = df_columns)

df_new
# Out:
# Empty DataFrame
# Columns: [Species, GMOR/, MORT, SURV, TDTH, HTCH, GMOR, TKNO, MDTH, TLET, SVVS, LFSP]
# Index: []

# %% [markdown]
# All the values for this tets table

# %%
df_trash  = df[df.species == 'norvegicus']

new_list  = []
for m in measurement_dict.keys():
    df_t  = df_trash[df_trash.measurement == m]
    new_list.append(str(df_t.shape[0]))

new_list.insert(0,'norvegicus')

new_list
a         = np.array(new_list)
new_list  = a.transpose().tolist()

print(new_list)
print(df_columns)
# Out:
# ['norvegicus', '60737', '12841', '5118', '40', '0', '1', '0', '0', '0', '0', '0']
# ['Species', 'GMOR/', 'MORT', 'SURV', 'TDTH', 'HTCH', 'GMOR', 'TKNO', 'MDTH', 'TLET', 'SVVS', 'LFSP']

# %% [markdown]
# Creating the final test table

# %%
current_row = pd.DataFrame([new_list], columns=df_columns)

current_row
# Out:
#       Species  GMOR/   MORT  SURV TDTH HTCH GMOR TKNO MDTH TLET SVVS LFSP
# 0  norvegicus  60737  12841  5118   40    0    1    0    0    0    0    0

# %% [markdown]
# Creating dict to get each value as unique id

# %%
species_dict = df['species'].value_counts().to_dict()
species_dict
# Out:
# {'norvegicus': 78737,
#  'musculus': 15544,
#  'platyrhynchos': 5882,
#  'colchicus': 5364,
#  'japonica': 5290,
#  'terrestris': 3808,
#  'rubripes': 3186,
#  'esculentus': 1813,
#  'candida': 1398,
#  'alba': 1260,
#  'sp.': 1239,
#  'andrei': 952,
#  'latrans': 919,
#  'scrofa': 882,
#  'sparverius': 849,
#  'domesticus': 834,
#  'fetida': 792,
#  'aries': 701,
#  'virginianus': 689,
#  'redividus': 416,
#  'hispidus': 370,
#  'vison': 348,
#  'mellifera': 318,
#  'quinquefasciatus': 296,
#  'auritus': 215,
#  'coturnix': 180,
#  'auratus': 145,
#  'porcellus': 130,
#  'rubellus': 109,
#  'scaber': 106,
#  'ater': 104,
#  'cuniculus': 101,
#  'ludovicianus': 98,
#  'caliginosa': 84,
#  'max': 83,
#  'stephensi': 63,
#  'confusum': 60,
#  'unicolor': 59,
#  'leucocephalus': 57,
#  'virescens': 56,
#  'sanguinalis': 54,
#  'vulgaris': 48,
#  'glabrum': 41,
#  'rosae': 40,
#  'quinquemaculata': 39,
#  'coffeella': 39,
#  'pennsylvanicus': 38,
#  'melanogaster': 36,
#  'pipiens': 34,
#  'aegypti': 31,
#  'livia': 31,
#  'migratorius': 28,
#  'frugiperda': 26,
#  'perenne': 24,
#  0: 22,
#  'veneta': 18,
#  'perpallidus': 18,
#  'hortensis': 16,
#  'guttata': 16,
#  'americana': 15,
#  'ipsilon': 15,
#  'domestica': 14,
#  'saucia': 12,
#  'zea': 11,
#  'crypticus': 11,
#  'unguiculatus': 11,
#  'v-nigrum': 11,
#  'littoralis': 11,
#  'convergens': 9,
#  'jacobsoni': 9,
#  'urticae': 9,
#  'armigera': 8,
#  'quiscula': 8,
#  'oregonensis': 8,
#  'armata': 8,
#  'elegans': 7,
#  'laevis': 7,
#  'lignaria': 7,
#  'mississippiensis': 6,
#  'moubata': 6,
#  'catesbeiana': 5,
#  'castaneum': 5,
#  'reticulatum': 5,
#  'chlorotica': 5,
#  'woodi': 4,
#  'sanguinea': 4,
#  'trivittatus': 4,
#  'messoria': 4,
#  'posthuma': 4,
#  'farinae': 4,
#  'marginiventris': 4,
#  'aspersa': 4,
#  'hemionus': 4,
#  'maximus': 4,
#  'maculatum': 4,
#  'scripta': 3,
#  'flavoviridis': 3,
#  'familiaris': 3,
#  'scandens': 3,
#  'formosanus': 3,
#  'rigidum': 2,
#  'inodorum': 2,
#  'lapathifolium': 2,
#  'exigua': 2,
#  'blomhoffii': 2,
#  'dilatatus': 2,
#  'germanica': 2,
#  'orientalis': 2,
#  'fulica': 2,
#  'phoeniceus': 2,
#  'discors': 2,
#  'rotundata': 1,
#  'papaya': 1,
#  'sponsa': 1,
#  'brunneus': 1,
#  'vulgare': 1,
#  'cincta': 1,
#  'gestroi': 1,
#  'arvensis': 1,
#  'rubra': 1,
#  'brassicae': 1,
#  'polionotus': 1}

# %% [markdown]
# Since the example worked, now we'll create an automatizated solution for all values in all columns

# %%
# for m in measurement_dict.keys():
#     new_df  = df.columns=[m]
    
# for s in species_dict.keys():
#     new_df  = df(rows=[s])
    
# for m in measurement_dict.keys():
#     new_df    = df[ df.measurement == m ]
#     for s in species_dict.keys():
        
#         new_df = df[df.species == s]
        
#         new_df[m][a] = df['measurement'].value_counts().to_dict().shape[0]

# %%
for m in measurement_dict.keys():
    new_df  = df.columns=[m]
print(new_df)
    
for s in species_dict.keys():
    new_df  = df(rows=[s])
print(new_df)

new_list  = []
for m in measurement_dict.keys():
    new_df    = df[ df.measurement == m ]
    for s in species_dict.keys():
        new_list.insert(0,s)
        new_df = df[df.species == s]
        new_df[m][a] = df['measurement'].value_counts().to_dict().shape[0]
        
a         = np.array(new_list)
new_list  = a.transpose().tolist()
current_row = pd.DataFrame([new_list], columns=df_columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-1515448b444b> in <module>
#       1 for m in measurement_dict.keys():
# ----> 2     new_df  = df.columns=[m]
#       3 print(new_df)
#       4
#       5 for s in species_dict.keys():
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5078         try:
#    5079             object.__getattribute__(self, name)
# -> 5080             return object.__setattr__(self, name, value)
#    5081         except AttributeError:
#    5082             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     636
#     637     def _set_axis(self, axis, labels):
# --> 638         self._data.set_axis(axis, labels)
#     639         self._clear_item_cache()
#     640
#
# /usr/local/lib/python3.7/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     153             raise ValueError(
#     154                 'Length mismatch: Expected axis has {old} elements, new '
# --> 155                 'values have {new} elements'.format(old=old_len, new=new_len))
#     156
#     157         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 35 elements, new values have 1 elements

# %% [markdown]
# # Using query
#
# Creating a filter proved to be a hard way to to something that there's already concepts in python that will help out

# %% [markdown]
# This function will show how many times a specific type of mortality effect occur for each species. As for example:
#
# andrei
# GMOR/           814
#
# MORT            138
#
# Andrei is a worm and it lives in compost or leaf litter. Also, in experimenting with this species, there was 814 cases of GMOR (this reference can be seen in past analysis) and 138 MORT, or 14% of Andrei had MORT effect with MORT measurement.

# %%
n = df.query('effect == "MOR"')
speciesMeasurement = n.groupby(['species', 'measurement']).size()
speciesMeasurement
# Out:
# species       measurement
# 0             MORT             15
#               SURV              6
#               TKNO              1
# aegypti       MORT             31
# alba          GMOR/          1260
# americana     MORT             15
# andrei        GMOR/           814
#               MORT            138
# aries         MORT            701
# armata        MORT              2
#               SURV              6
# armigera      MORT              8
# arvensis      MORT              1
# aspersa       MORT              4
# ater          MORT            104
# auratus       MORT             10
#               SURV            135
# auritus       SURV            215
# blomhoffii    MORT              2
# brassicae     SURV              1
# brunneus      MORT              1
# caliginosa    MORT             79
#               SURV              5
# candida       MORT           1174
#               SURV            224
# castaneum     MORT              3
#               TLET              2
# catesbeiana   MORT              5
# chlorotica    SURV              5
# cincta        GMOR              1
#                              ...
# saucia        MORT             12
# scaber        MORT            106
# scandens      MORT              3
# scripta       MORT              3
# scrofa        MORT            882
# sp.           GMOR/          1052
#               MORT            186
#               SURV              1
# sparverius    GMOR/           630
#               MORT            219
# sponsa        SURV              1
# stephensi     GMOR              4
#               MORT             59
# terrestris    MORT           3808
# trivittatus   MORT              4
# unguiculatus  GMOR/             6
#               MORT              5
# unicolor      GMOR             49
#               TKNO             10
# urticae       MORT              9
# v-nigrum      MORT             11
# veneta        MORT             18
# virescens     MORT             56
# virginianus   MORT            689
# vison         MORT            348
# vulgare       MORT              1
# vulgaris      MORT             46
#               SURV              2
# woodi         MORT              4
# zea           MORT             11
# Length: 169, dtype: int64

# %%
n['species']
# Out:
# 32         posthuma
# 33         posthuma
# 34         posthuma
# 35         posthuma
# 1206          vison
# 1207          vison
# 1208          vison
# 1209          vison
# 1210          vison
# 1211          vison
# 1212          vison
# 1213          vison
# 1214          vison
# 1215          vison
# 1216          vison
# 1217          vison
# 1218          vison
# 1219          vison
# 1220          vison
# 1221          vison
# 1222          vison
# 1223          vison
# 1224          vison
# 1225          vison
# 1226          vison
# 1227          vison
# 1228          vison
# 1229          vison
# 1230          vison
# 1231          vison
#              ...
# 1630068     glabrum
# 1630069     glabrum
# 1630070     glabrum
# 1630071     glabrum
# 1630072     glabrum
# 1630073     glabrum
# 1630074     glabrum
# 1630075     glabrum
# 1630076     glabrum
# 1630077     glabrum
# 1630078     glabrum
# 1630079     glabrum
# 1630080     glabrum
# 1630081     glabrum
# 1630082     glabrum
# 1630083     glabrum
# 1630084     glabrum
# 1630085     glabrum
# 1630086     glabrum
# 1630087     glabrum
# 1630088     glabrum
# 1630089     glabrum
# 1630090     glabrum
# 1630091     glabrum
# 1630092     glabrum
# 1630093     glabrum
# 1630094     glabrum
# 1630095     glabrum
# 1630096     glabrum
# 1630097     glabrum
# Name: species, Length: 134451, dtype: object

# %%
set(df['measurement'])
# Out:
# {'GMOR',
#  'GMOR/',
#  'HTCH',
#  'LFSP',
#  'MDTH',
#  'MORT',
#  'SURV',
#  'SVVS',
#  'TDTH',
#  'TKNO',
#  'TLET'}

# %%
n.groupby(['species', 'measurement']).describe()
# Out:
#                          test_id                     test_cas         \
#                            count unique     top freq    count unique
# species      measurement
# 0            MORT             15     15  538515    1       15     15
#              SURV              6      2    4969    3        6      2
#              TKNO              1      1  556175    1        1      1
# aegypti      MORT             31     31  520128    1       31      7
# alba         GMOR/          1260      2   51883  672     1260      2
# americana    MORT             15      2    2867   12       15      2
# andrei       GMOR/           814      4   46559  350      814      3
#              MORT            138      9   46244   56      138      4
# aries        MORT            701      6   51748  627      701      6
# armata       MORT              2      2   57535    1        2      1
#              SURV              6      6  423498    1        6      1
# armigera     MORT              8      8  554857    1        8      5
# arvensis     MORT              1      1   53989    1        1      1
# aspersa      MORT              4      4   49828    1        4      4
# ater         MORT            104      6   54775   85      104      3
# auratus      MORT             10     10  561684    1       10      2
#              SURV            135      2   53649  106      135      2
# auritus      SURV            215      8   54933  208      215      2
# blomhoffii   MORT              2      2  556170    1        2      2
# brassicae    SURV              1      1  423614    1        1      1
# brunneus     MORT              1      1  521481    1        1      1
# caliginosa   MORT             79      4   46853   20       79      2
#              SURV              5      5   54285    1        5      5
# candida      MORT           1174    119    5258   10     1174     32
#              SURV            224     23    5021   16      224      8
# castaneum    MORT              3      3  517080    1        3      2
#              TLET              2      2   49804    1        2      1
# catesbeiana  MORT              5      1   48021    5        5      1
# chlorotica   SURV              5      5   53790    1        5      5
# cincta       GMOR              1      1  586971    1        1      1
# ...                          ...    ...     ...  ...      ...    ...
# saucia       MORT             12      3   48763    4       12      1
# scaber       MORT            106      1   52348  106      106      1
# scandens     MORT              3      3  522958    1        3      3
# scripta      MORT              3      3  474268    1        3      3
# scrofa       MORT            882      2   52374  592      882      1
# sp.          GMOR/          1052     25   51359   44     1052     25
#              MORT            186     14   51793   80      186     13
#              SURV              1      1  591219    1        1      1
# sparverius   GMOR/           630      2   53903  480      630      2
#              MORT            219      4   53020  191      219      3
# sponsa       SURV              1      1  562660    1        1      1
# stephensi    GMOR              4      4  579197    1        4      1
#              MORT             59     59  579182    1       59      3
# terrestris   MORT           3808     25   47412  756     3808     22
# trivittatus  MORT              4      2   51564    2        4      2
# unguiculatus GMOR/             6      1    2672    6        6      1
#              MORT              5      1   54151    5        5      1
# unicolor     GMOR             49     49  550990    1       49     21
#              TKNO             10     10  550695    1       10      7
# urticae      MORT              9      9  428584    1        9      1
# v-nigrum     MORT             11     11  572127    1       11     11
# veneta       MORT             18      1   49766   18       18      1
# virescens    MORT             56     56  491943    1       56     12
# virginianus  MORT            689     12     458  492      689      4
# vison        MORT            348      1      50  348      348      1
# vulgare      MORT              1      1   52394    1        1      1
# vulgaris     MORT             46      1   53584   46       46      1
#              SURV              2      2  432311    1        2      2
# woodi        MORT              4      4  450383    1        4      1
# zea          MORT             11     11  512701    1       11      6
#
#                                          organism_lifestage         ...  \
#                                 top freq              count unique  ...
# species      measurement                                            ...
# 0            MORT           7447418    1                 15      1  ...
#              SURV             58899    3                  6      1  ...
#              TKNO          52645531    1                  1      1  ...
# aegypti      MORT          52645531    7                 31      1  ...
# alba         GMOR/            72559  672               1260      1  ...
# americana    MORT             60571   12                 15      1  ...
# andrei       GMOR/           118967  362                814      1  ...
#              MORT            118967  108                138      1  ...
# aries        MORT           7646799  627                701      3  ...
# armata       MORT            129000    2                  2      1  ...
#              SURV            129000    6                  6      1  ...
# armigera     MORT          71751412    3                  8      1  ...
# arvensis     MORT           1773371    1                  1      1  ...
# aspersa      MORT             64471    1                  4      1  ...
# ater         MORT             50293   90                104      1  ...
# auratus      MORT           3813147    7                 10      1  ...
#              SURV             72559  106                135      1  ...
# auritus      SURV             50293  208                215      2  ...
# blomhoffii   MORT           8003347    1                  2      1  ...
# brassicae    SURV         161050584    1                  1      1  ...
# brunneus     MORT          12789036    1                  1      1  ...
# caliginosa   MORT           7758987   40                 79      1  ...
#              SURV            116063    1                  5      1  ...
# candida      MORT             60571   70               1174      2  ...
#              SURV          10108642   60                224      3  ...
# castaneum    MORT          52645531    2                  3      2  ...
#              TLET          52645531    2                  2      1  ...
# catesbeiana  MORT           1746016    5                  5      1  ...
# chlorotica   SURV            116063    1                  5      1  ...
# cincta       GMOR           1912249    1                  1      1  ...
# ...                             ...  ...                ...    ...  ...
# saucia       MORT          16752775   12                 12      1  ...
# scaber       MORT             50328  106                106      1  ...
# scandens     MORT          51630581    1                  3      1  ...
# scripta      MORT             72559    1                  3      1  ...
# scrofa       MORT            301042  882                882      1  ...
# sp.          GMOR/          6369591   44               1052      1  ...
#              MORT           6080564   80                186      5  ...
#              SURV           1912249    1                  1      1  ...
# sparverius   GMOR/           115322  480                630      2  ...
#              MORT           7439921  191                219      2  ...
# sponsa       SURV            298000    1                  1      1  ...
# stephensi    GMOR          52645531    4                  4      1  ...
#              MORT          29232937   44                 59      1  ...
# terrestris   MORT             63252  758               3808      2  ...
# trivittatus  MORT            121755    2                  4      1  ...
# unguiculatus GMOR/          7786347    6                  6      1  ...
#              MORT           7786347    5                  5      1  ...
# unicolor     GMOR          26002802   14                 49      1  ...
#              TKNO          23031369    3                 10      1  ...
# urticae      MORT          15708415    9                  9      1  ...
# v-nigrum     MORT             76879    1                 11      1  ...
# veneta       MORT           7718549   18                 18      1  ...
# virescens    MORT          52645531   16                 56      2  ...
# virginianus  MORT             60571  664                689      5  ...
# vison        MORT          32774166  348                348      1  ...
# vulgare      MORT            309002    1                  1      1  ...
# vulgaris     MORT             50293   46                 46      1  ...
#              SURV           2921882    1                  2      1  ...
# woodi        MORT          33089611    4                  4      2  ...
# zea          MORT          52315078    6                 11      2  ...
#
#                                   class       tax_order         \
#                                     top  freq     count unique
# species      measurement
# 0            MORT                     0    12        15      3
#              SURV            Clitellata     6         6      1
#              TKNO             Arachnida     1         1      1
# aegypti      MORT               Insecta    31        31      1
# alba         GMOR/                 Aves  1260      1260      1
# americana    MORT               Insecta    15        15      1
# andrei       GMOR/           Clitellata   814       814      1
#              MORT            Clitellata   138       138      1
# aries        MORT              Mammalia   701       701      1
# armata       MORT            Entognatha     2         2      1
#              SURV            Entognatha     6         6      1
# armigera     MORT               Insecta     8         8      1
# arvensis     MORT         Magnoliopsida     1         1      1
# aspersa      MORT            Gastropoda     4         4      1
# ater         MORT                  Aves   104       104      1
# auratus      MORT              Mammalia    10        10      1
#              SURV              Mammalia   135       135      1
# auritus      SURV                  Aves   215       215      1
# blomhoffii   MORT              Reptilia     2         2      1
# brassicae    SURV               Insecta     1         1      1
# brunneus     MORT               Insecta     1         1      1
# caliginosa   MORT            Clitellata    79        79      1
#              SURV            Clitellata     5         5      1
# candida      MORT            Entognatha  1174      1174      1
#              SURV            Entognatha   224       224      1
# castaneum    MORT               Insecta     3         3      1
#              TLET               Insecta     2         2      1
# catesbeiana  MORT              Amphibia     5         5      1
# chlorotica   SURV            Clitellata     5         5      1
# cincta       GMOR            Entognatha     1         1      1
# ...                                 ...   ...       ...    ...
# saucia       MORT               Insecta    12        12      1
# scaber       MORT          Malacostraca   106       106      1
# scandens     MORT               Insecta     3         3      1
# scripta      MORT              Reptilia     3         3      1
# scrofa       MORT              Mammalia   882       882      1
# sp.          GMOR/             Mammalia  1052      1052      1
#              MORT              Mammalia    92       186      5
#              SURV              Reptilia     1         1      1
# sparverius   GMOR/                 Aves   630       630      1
#              MORT                  Aves   219       219      1
# sponsa       SURV                  Aves     1         1      1
# stephensi    GMOR               Insecta     4         4      1
#              MORT               Insecta    59        59      1
# terrestris   MORT            Clitellata  3808      3808      1
# trivittatus  MORT               Insecta     4         4      1
# unguiculatus GMOR/             Mammalia     6         6      1
#              MORT              Mammalia     5         5      1
# unicolor     GMOR               Insecta    49        49      1
#              TKNO               Insecta    10        10      1
# urticae      MORT             Arachnida     9         9      1
# v-nigrum     MORT               Insecta    11        11      1
# veneta       MORT            Clitellata    18        18      1
# virescens    MORT               Insecta    56        56      1
# virginianus  MORT                  Aves   673       689      2
# vison        MORT              Mammalia   348       348      1
# vulgare      MORT          Malacostraca     1         1      1
# vulgaris     MORT                  Aves    46        46      1
#              SURV                  Aves     2         2      1
# woodi        MORT             Arachnida     4         4      1
# zea          MORT               Insecta    11        11      1
#
#                                                 family         \
#                                       top  freq  count unique
# species      measurement
# 0            MORT                       0    12     15      1
#              SURV            Lumbriculida     6      6      1
#              TKNO              Scorpiones     1      1      1
# aegypti      MORT                 Diptera    31     31      1
# alba         GMOR/           Strigiformes  1260   1260      1
# americana    MORT             Dictyoptera    15     15      1
# andrei       GMOR/           Lumbriculida   814    814      1
#              MORT            Lumbriculida   138    138      1
# aries        MORT            Artiodactyla   701    701      1
# armata       MORT              Collembola     2      2      1
#              SURV              Collembola     6      6      1
# armigera     MORT             Lepidoptera     8      8      1
# arvensis     MORT             Brassicales     1      1      1
# aspersa      MORT         Stylommatophora     4      4      1
# ater         MORT           Passeriformes   104    104      1
# auratus      MORT                Rodentia    10     10      1
#              SURV                Rodentia   135    135      1
# auritus      SURV              Suliformes   215    215      1
# blomhoffii   MORT                Squamata     2      2      1
# brassicae    SURV             Hymenoptera     1      1      1
# brunneus     MORT              Coleoptera     1      1      1
# caliginosa   MORT            Lumbriculida    79     79      1
#              SURV            Lumbriculida     5      5      1
# candida      MORT              Collembola  1174   1174      1
#              SURV              Collembola   224    224      1
# castaneum    MORT              Coleoptera     3      3      1
#              TLET              Coleoptera     2      2      1
# catesbeiana  MORT                   Anura     5      5      1
# chlorotica   SURV            Lumbriculida     5      5      1
# cincta       GMOR              Collembola     1      1      1
# ...                                   ...   ...    ...    ...
# saucia       MORT             Lepidoptera    12     12      1
# scaber       MORT                 Isopoda   106    106      1
# scandens     MORT             Lepidoptera     3      3      1
# scripta      MORT              Testudines     3      3      1
# scrofa       MORT            Artiodactyla   882    882      1
# sp.          GMOR/               Rodentia  1052   1052      1
#              MORT                Rodentia    91    186      7
#              SURV              Testudines     1      1      1
# sparverius   GMOR/          Falconiformes   630    630      1
#              MORT           Falconiformes   219    219      1
# sponsa       SURV            Anseriformes     1      1      1
# stephensi    GMOR                 Diptera     4      4      1
#              MORT                 Diptera    59     59      1
# terrestris   MORT            Lumbriculida  3808   3808      1
# trivittatus  MORT                 Diptera     4      4      1
# unguiculatus GMOR/               Rodentia     6      6      1
#              MORT                Rodentia     5      5      1
# unicolor     GMOR              Coleoptera    49     49      1
#              TKNO              Coleoptera    10     10      1
# urticae      MORT          Trombidiformes     9      9      1
# v-nigrum     MORT              Coleoptera    11     11      1
# veneta       MORT            Lumbriculida    18     18      1
# virescens    MORT             Lepidoptera    56     56      1
# virginianus  MORT             Galliformes   673    689      2
# vison        MORT               Carnivora   348    348      1
# vulgare      MORT                 Isopoda     1      1      1
# vulgaris     MORT           Passeriformes    46     46      1
#              SURV           Passeriformes     2      2      1
# woodi        MORT          Trombidiformes     4      4      1
# zea          MORT             Lepidoptera    11     11      1
#
#
#                                         top  freq
# species      measurement
# 0            MORT                         0    15
#              SURV               Lumbricidae     6
#              TKNO                         0     1
# aegypti      MORT                 Culicidae    31
# alba         GMOR/                Tytonidae  1260
# americana    MORT                 Blattidae    15
# andrei       GMOR/              Lumbricidae   814
#              MORT               Lumbricidae   138
# aries        MORT                   Bovidae   701
# armata       MORT              Onychiuridae     2
#              SURV              Onychiuridae     6
# armigera     MORT                 Noctuidae     8
# arvensis     MORT              Brassicaceae     1
# aspersa      MORT                 Helicidae     4
# ater         MORT              Fringillidae   104
# auratus      MORT                   Muridae    10
#              SURV                   Muridae   135
# auritus      SURV         Phalacrocoracidae   215
# blomhoffii   MORT                 Viperidae     2
# brassicae    SURV         Trichogrammatidae     1
# brunneus     MORT              Bostrichidae     1
# caliginosa   MORT               Lumbricidae    79
#              SURV               Lumbricidae     5
# candida      MORT                Isotomidae  1174
#              SURV                Isotomidae   224
# castaneum    MORT             Tenebrionidae     3
#              TLET             Tenebrionidae     2
# catesbeiana  MORT                   Ranidae     5
# chlorotica   SURV               Lumbricidae     5
# cincta       GMOR             Entomobryidae     1
# ...                                     ...   ...
# saucia       MORT                 Noctuidae    12
# scaber       MORT            Porcellionidae   106
# scandens     MORT                 Noctuidae     3
# scripta      MORT                  Emydidae     3
# scrofa       MORT                    Suidae   882
# sp.          GMOR/                  Muridae  1052
#              MORT                   Muridae    88
#              SURV                  Emydidae     1
# sparverius   GMOR/               Falconidae   630
#              MORT                Falconidae   219
# sponsa       SURV                  Anatidae     1
# stephensi    GMOR                 Culicidae     4
#              MORT                 Culicidae    59
# terrestris   MORT               Lumbricidae  3808
# trivittatus  MORT                 Culicidae     4
# unguiculatus GMOR/                  Muridae     6
#              MORT                   Muridae     5
# unicolor     GMOR                 Anobiidae    49
#              TKNO                 Anobiidae    10
# urticae      MORT             Tetranychidae     9
# v-nigrum     MORT             Coccinellidae    11
# veneta       MORT               Lumbricidae    18
# virescens    MORT                 Noctuidae    56
# virginianus  MORT            Odontophoridae   673
# vison        MORT                Mustelidae   348
# vulgare      MORT           Armadillidiidae     1
# vulgaris     MORT                 Sturnidae    46
#              SURV                 Sturnidae     2
# woodi        MORT              Tarsonemidae     4
# zea          MORT                 Noctuidae    11
#
# [169 rows x 132 columns]

# %% [markdown]
# ### Creating graph with analysis info

# %%
groups = speciesMeasurement
groups.plot.bar()

# %%
fig, ax = plt.subplots(figsize=(20,7))
speciesMeasurement.unstack().plot(ax=ax)

#data.groupby(['date','type']).count()['amount'].unstack().plot(ax=ax)

# %% [markdown]
# Obviously the analysis like that is too verbose and brings no quality in data understanding. One way to solve this, would be conting which species had more occurrencies in each ```measument``` type

# %% [markdown]
# ### Top 5 species in each measument occurrency

# %% [markdown]
# # TODO

# %% [markdown]
# ### Undestanding the mean value

# %% [markdown]
# Cant use ```.mean()``` directly in ```n.groupby(['species', 'measurement'])``` because the value is cathegorical.

# %% [markdown]
# # TODO

# %%
n.groupby(['species', 'measurement']).mean()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-17-056eb6fa541b> in <module>
# ----> 1 n.groupby(['species', 'measurement']).mean()
#
# /usr/local/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in mean(self, *args, **kwargs)
#    1130         nv.validate_groupby_func('mean', args, kwargs, ['numeric_only'])
#    1131         try:
# -> 1132             return self._cython_agg_general('mean', **kwargs)
#    1133         except GroupByError:
#    1134             raise
#
# /usr/local/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#      68                             min_count=-1):
#      69         new_items, new_blocks = self._cython_agg_blocks(
# ---> 70             how, alt=alt, numeric_only=numeric_only, min_count=min_count)
#      71         return self._wrap_agged_blocks(new_items, new_blocks)
#      72
#
# /usr/local/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#     141
#     142         if len(new_blocks) == 0:
# --> 143             raise DataError('No numeric types to aggregate')
#     144
#     145         # reset the locs in the blocks to correspond to our
#
# DataError: No numeric types to aggregate
