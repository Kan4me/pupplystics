# %%
import pandas as pd
import numpy as np
from matplotlib import rc
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# A new analysis to be done is the relation of chemicals and its effect expected over the years.

# %%
df = pd.read_csv('../data/treated_data/table_reference_date_info.csv')
# Out:
# /usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3044: DtypeWarning: Columns (5,7,8,10,11,18,23,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.iloc[:5]
# Out:
#    Unnamed: 0  test_id  test_cas organism_lifestage  species_number  \
# 0           0       13     50293                 NR            5022
# 1           1       13     50293                 NR            5022
# 2           2       13     50293                 NR            5022
# 3           3       13     50293                 NR            5022
# 4           4       13     50293                 NR            5022
#
#   organism_age_mean organism_gender study_duration_mean  \
# 0                NR              NR                   8
# 1                NR              NR                   8
# 2                NR              NR                   8
# 3                NR              NR                   8
# 4                NR              NR                   8
#
#   exposure_duration_mean test_type  ...    chem_name formulation  \
# 0                      8        NC  ...  2-Propanone          NR
# 1                      8        NC  ...  2-Propanone          NR
# ...

# %%
n = df.query('effect == "MOR"')
relation = n.groupby(['publication_year', 'chemical_name', 'measurement']).size()

# %%
relation.iloc[:20]
# Out:
# publication_year  chemical_name            measurement
# 1944              Olive oil                MORT               1
# 1946              Corn oil                 SURV              15
# 1947              Corn oil                 MORT             519
# 1950              Aluminatesilicate        MORT               1
# 1951              Ethanol                  GMOR/          51372
#                                            MORT             560
#                   Water                    MORT             627
# 1952              Corn oil                 MORT               3
# 1953              Ethanol                  MORT             768
# 1954              Ethanol                  MORT            6606
# 1955              Cellulose, Methyl ether  MORT              64
#                   Gum arabic               MORT              46
#                   Water                    SURV               6
# 1964              2-Propanone              MORT              38
# ...

# %%
relation.plot(kind='area', figsize=(20,10))

# %%
dfObj = pd.DataFrame(relation, columns = ['size'])
dfObj
# Out:
#                                                                                size
# publication_year chemical_name                                   measurement
# 1944             Olive oil                                       MORT             1
# 1946             Corn oil                                        SURV            15
# 1947             Corn oil                                        MORT           519
# 1950             Aluminatesilicate                               MORT             1
# 1951             Ethanol                                         GMOR/        51372
#                                                                  MORT           560
#                  Water                                           MORT           627
# 1952             Corn oil                                        MORT             3
# 1953             Ethanol                                         MORT           768
# ...
